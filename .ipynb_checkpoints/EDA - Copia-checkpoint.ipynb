# %% [markdown]
# # Modules used in this project

# %%
# standard libraries
import os
import time
from datetime import datetime
import itertools
from itertools import chain, combinations
import warnings
warnings.filterwarnings('ignore')

# data analysis and manipulation
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# machine learning and model selection
from sklearn.model_selection import train_test_split, TimeSeriesSplit, ParameterGrid
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb
from xgboost import XGBRegressor

# statistical tools and analysis
from scipy.stats import pearsonr, shapiro
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# APIs and requests
import requests
import json

import time

# %% [markdown]
# # Functions used in this project

# %% [markdown]
# ## Data visualization

# %%
def scatter_plots(df):
    columns = df.columns
    combinations = list(itertools.combinations(columns, 2))  
    for col1, col2 in combinations:
        plt.figure(figsize=(6, 4))
        sns.scatterplot(x=df[col1], y=df[col2])
        plt.title(f'Scatter Plot: {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.grid(True)
        plt.show()

# %%
def plot_residuals(residuals_df):
    num_columns = len(residuals_df.columns)
    
    fig, axes = plt.subplots(nrows=num_columns, ncols=1, figsize=(10, 6 * num_columns), sharex=True)
    
    for i, column in enumerate(residuals_df.columns):
        axes[i].plot(residuals_df.index, residuals_df[column], label=f'Resíduo - {column}')
        axes[i].axhline(0, color='black', linewidth=1)
        axes[i].set_ylabel('Resíduos')
        axes[i].set_title(f'Resíduos - {column}')
        axes[i].legend()
    
    axes[-1].set_xlabel('Tempo')  
    plt.tight_layout()  
    plt.show()

# %%
def plot_autocorrelation(df, n_lags, autocorrelation_function):

    if autocorrelation_function == "ACF":
        for column in df.columns:
            plot_acf(df[column], lags = n_lags)
            plt.title(f"ACF for {column}")
            plt.tight_layout() 
            
    elif autocorrelation_function == "PACF":
        for column in df.columns:
                plot_pacf(df[column], lags = n_lags)
                plt.title(f"PACF for {column}")
                plt.tight_layout()
            
    else:
        print("Invalid autocorrelation function. Please try 'ACF' or 'PACF'")

# %% [markdown]
# ## Statistics and data analysis

# %%
def correlation_with_lags(target_series, series_dict, max_lag):
    correlations = {}
    
    # Iterar sobre cada série no dicionário
    for series_name, other_series in series_dict.items():
        
        # Dicionário para armazenar as correlações de uma única série
        series_correlations = {}
        
        for lag in range(max_lag + 1):
            # Defasagem da outra série
            shifted_series = other_series.shift(lag)
            
            # Calcular correlação entre a série alvo e a série defasada
            correlation = target_series.corr(shifted_series)
            
            # Armazenar a correlação com o nome da coluna correspondente ao lag
            series_correlations[f'corr_lag_{lag}'] = correlation
        
        # Armazenar as correlações dessa série
        correlations[series_name] = series_correlations
    
    # Converter o dicionário em DataFrame
    result_df = pd.DataFrame(correlations).T 
    
    return result_df

# %%
def check_stationarity(series):
    result = adfuller(series)
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    if result[1] > 0.05:
        print("A série não é estacionária (p > 0.05)")
    else:
        print("A série é estacionária (p <= 0.05)")

# %%
def shapiro_test(residuals_df):
    for column in residuals_df.columns:
        stat, p_value = shapiro(residuals_df[column])
        if p_value < 0.05:
            print(f"Variável: {column}, estatística: {stat}, p-value: {p_value}. Hipótese nula rejeitada. Os resíduos não são normalmente distribuídos")
        else: 
            print(f"Variável: {column}, estatística: {stat}, p-value: {p_value}. Hipótese nula não foi rejeitada. Os resíduos são normalmente distribuídos")

# %% [markdown]
# ## Data preprocessing and manipulation

# %%
def split_train_test(X, y, train_size=0.8):
    split_index = int(len(X) * train_size)
    X_train, X_test = X.iloc[:split_index], X.iloc[split_index:]
    y_train, y_test = y.iloc[:split_index], y.iloc[split_index:]
    return X_train, X_test, y_train, y_test

# %%
def convert_unix_milliseconds_to_date(unix_milliseconds):
    # Convert milliseconds to seconds
    unix_seconds = unix_milliseconds / 1000
    # Create a datetime object from the Unix timestamp
    dt = datetime.fromtimestamp(unix_seconds)
    # Format the datetime object to a string in day/month/year format
    return dt.strftime('%d/%m/%Y')

# %%
def convert_to_date(df, date_column, freq='h'):
    df = df.assign(date=list(map(lambda x: convert_unix_milliseconds_to_date(x), 
                                        df[date_column])))
    df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
    df['hour'] = pd.date_range(start='00:00', periods=len(df), freq=freq).time
    df['date_hour'] = df['date'] + pd.to_timedelta(df.groupby('date').cumcount(), unit=freq)
    df.index = df['date_hour']
    df = df.drop('date_hour', axis=1)
    return df

# %%
def get_all_combinations(columns):
    return list(chain.from_iterable(combinations(columns, r) for r in range(1, len(columns) + 1)))

# %%
def add_lags(df, num_lags):
    
    lagged_df = df.copy()

    for lag in range(1, num_lags + 1):
        lagged_columns = {
            f"{col}_lag_{lag}": df[col].shift(lag)
            for col in df.columns
        }
        lagged_df = pd.concat([lagged_df, pd.DataFrame(lagged_columns)], axis=1)

    lagged_df.dropna(inplace=True)

    return lagged_df

# %% [markdown]
# ## Model training

# %%
def one_step_ahead_forecasting(X, y, model, starting_point):
    '''predict the next observation of a time series using as training set all the past observations'''
    
    predictions = np.array([])
    print('Treinando')
    X_train, X_test, y_train, y_test = training_test_split(X, y, starting_point = starting_point)
    print('Fit')
    model.fit(X_train.values, y_train.values)
    print('Fit final')
    for i in range(len(X_test)):
        predictions = np.append(predictions, (model.predict(X_test.iloc[i].values.reshape(1, -1))))
        print('Predição')
        X_train = pd.concat([X_train, X_test.iloc[i].to_frame().T])
        y_train = np.append(y_train, y_test.iloc[i].reshape(1, -1))
        
        y_train = pd.Series(y_train)
        
        model.fit(X_train.values, y_train.values)
        
    return predictions

# %%
def one_step_ahead_forecasting_AR(y, starting_point_percent, lags):
    '''Faz previsão one-step-ahead utilizando modelo autoregressivo (AR) e um ponto de início baseado em porcentagem'''
    
    predictions = np.array([])
    print(f'Treinando modelo AR com {lags} lags')

    # Definindo o ponto de início como porcentagem dos dados
    starting_point = int(len(y) * starting_point_percent)
    
    # Dividindo o conjunto de treino e teste a partir do ponto de início
    y_train = y[:starting_point]
    y_test = y[starting_point:]

    # Criando o modelo autoregressivo inicial
    model = AutoReg(y_train, lags=lags)
    model_fit = model.fit()

    # Previsão one-step-ahead
    for i in range(len(y_test)):
        # Prevendo o próximo valor (one-step-ahead)
        pred = model_fit.predict(start=len(y_train), end=len(y_train), dynamic=False)
        predictions = np.append(predictions, pred)
        
        # Adiciona o valor real ao conjunto de treino
        y_train = np.append(y_train, y_test.iloc[i])
        
        # Ajusta o modelo novamente com o novo valor adicionado
        model = AutoReg(y_train, lags=lags)
        model_fit = model.fit()
    
    return predictions

# %%
def fit_ar_model(df, starting_point_percent, lags_list):
    '''Treina o modelo AR com uma lista de lags e retorna DataFrames de performance e resíduos'''
    
    performance_dict = {}
    residuals_dict = {}

    for lags in lags_list:
        print(f'Treinando para {lags} lags')
        
        for column in df.columns:
            print(f'Treinando com a variável: {column}')
            
            # Previsão com AR
            predictions = one_step_ahead_forecasting_AR(y=df[column], starting_point_percent=starting_point_percent, lags=lags)
            
            # Avaliando a performance
            actual = df[column].iloc[int(len(df[column]) * starting_point_percent):]
            mse, mae = evaluate_performance(predictions=predictions, actual=actual)
            performance_dict[(column, lags)] = [mse, mae]

            # Calculando os resíduos
            residuals = predictions - actual.values
            residuals_dict[(column, lags)] = residuals

            # Modelo Naive: previsão t = valor de t-1 para a variável
            predictions_naive = df[column].shift(1).iloc[int(len(df[column]) * starting_point_percent):]
            predictions_naive = predictions_naive.dropna()
            mse_naive, mae_naive = evaluate_performance(predictions=predictions_naive, actual=actual)
            performance_dict[('Naive_' + column, lags)] = [mse_naive, mae_naive]
    
    # Convertendo os dicionários de performance e resíduos para DataFrames
    performance_df = pd.DataFrame.from_dict(performance_dict, orient='index', columns=['MSE', 'MAE'])
    performance_df.index = pd.MultiIndex.from_tuples(performance_df.index, names=["Variable", "Lags"])
    
    # Resíduos: Cada variável terá seus resíduos para cada lag
    residuals_df = pd.DataFrame(residuals_dict)
    residuals_df.columns = pd.MultiIndex.from_tuples(residuals_df.columns, names=["Variable", "Lags"])
    residuals_df.index = df[column].iloc[int(len(df[column]) * starting_point_percent):].index[:len(residuals_df)]

    return performance_df, residuals_df

# %%
def one_step_ahead_forecasting_AR_exog(y, X, starting_point_percent, lags):
    """Faz previsão one-step-ahead utilizando modelo autoregressivo (AR) com variáveis exógenas e lags."""
    predictions = []
    print('Treinando modelo AR com variáveis exógenas e lags')
    
    # Definir o ponto de início
    starting_point = int(len(y) * starting_point_percent)
    
    # Dividindo o conjunto de treino e teste
    y_train = y[:starting_point].values  # Convertendo para numpy array
    y_test = y[starting_point:].values  # Convertendo para numpy array
    
    X_train = X.iloc[:starting_point].values  # Garantindo formato correto
    X_test = X.iloc[starting_point:].values  # Garantindo formato correto
    
    # Criar e ajustar o modelo inicial
    model = AutoReg(y_train, lags=lags, exog=X_train)
    model_fit = model.fit()
    print('Modelo ajustado')
    
    for i in range(len(y_test)):
        print(f'Predição passo {i+1}')
        
        if i >= len(X_test):  # Evita erro de indexação
            break
        
        exog_oos = X_test[i].reshape(1, -1)  # Garantir que exog seja 2D
        pred = model_fit.predict(start=len(y_train), end=len(y_train), exog_oos=exog_oos, dynamic=False)
        
        if pred.size > 0:
            predictions.append(pred[0])
        else:
            predictions.append(np.nan)  # Evita erro caso a previsão falhe
        
        # Atualizar conjunto de treino
        y_train = np.append(y_train, y_test[i])
        X_train = np.vstack([X_train, X_test[i]])
        
        # Ajustar modelo novamente
        model = AutoReg(y_train, lags=lags, exog=X_train)
        model_fit = model.fit()
    
    return np.array(predictions)

# %%
def fit_ar_model_exog(df, target_column, starting_point_percent, lags_list):
    """Treina o modelo AR com variáveis exógenas para diferentes lags e retorna DataFrames de performance e resíduos."""
    performance_dict = {}
    residuals_dict = {}
    
    y = df[target_column]
    X = df.drop(target_column, axis=1)
    
    # Gerar todas as combinações possíveis das variáveis exógenas
    exog_combinations = get_all_combinations(X.columns)
    
    for lags in lags_list:
        print(f'Treinando para {lags} lags')
        
        for combo in exog_combinations:
            print(f'Treinando com variáveis exógenas: {combo}')
            
            X_subset = X[list(combo)]  # Seleciona as colunas da combinação
            
            predictions = one_step_ahead_forecasting_AR_exog(y=y, X=X_subset, starting_point_percent=starting_point_percent, lags=lags)
            
            actual = y.iloc[int(len(y) * starting_point_percent):].values
            actual = actual[:len(predictions)]  # Garantir tamanhos compatíveis
            
            if len(predictions) != len(actual):
                print(f"Inconsistência de tamanho! Predictions: {len(predictions)}, Actual: {len(actual)}")
                continue
            
            mse, mae = evaluate_performance(predictions=predictions, actual=actual)
            performance_dict[(combo, lags)] = [mse, mae]
            
            residuals = predictions - actual
            residuals_dict[(combo, lags)] = residuals
            
            # Modelo Naive
            predictions_naive = y.shift(1).iloc[int(len(y) * starting_point_percent):].dropna().values
            predictions_naive = predictions_naive[:len(actual)]
            
            if len(predictions_naive) != len(actual):
                continue
            
            mse_naive, mae_naive = evaluate_performance(predictions=predictions_naive, actual=actual)
            performance_dict[('Naive_' + '_'.join(combo), lags)] = [mse_naive, mae_naive]
    
    # Convertendo os dicionários de performance e resíduos para DataFrames
    performance_df = pd.DataFrame.from_dict(performance_dict, orient='index', columns=['MSE', 'MAE'])
    performance_df.index = pd.MultiIndex.from_tuples(performance_df.index, names=["Variables", "Lags"])
    
    residuals_df = pd.DataFrame(residuals_dict)
    residuals_df.columns = pd.MultiIndex.from_tuples(residuals_df.columns, names=["Variables", "Lags"])
    residuals_df.index = y.iloc[int(len(y) * starting_point_percent):].index[:len(residuals_df)]
    
    return performance_df, residuals_df

# %% [markdown]
# ## Model validation

# %%
def time_series_cross_validation(X_train, y_train, model, n_splits=5):
    tscv = TimeSeriesSplit(n_splits=n_splits)
    errors = []

    # Iniciar o contador de tempo
    start_time = time.time()

    for train_index, val_index in tscv.split(X_train):
        X_t, X_val = X_train.iloc[train_index], X_train.iloc[val_index]
        y_t, y_val = y_train.iloc[train_index], y_train.iloc[val_index]

        model.fit(X_t, y_t)
        predictions = model.predict(X_val)

        mse = mean_squared_error(y_val, predictions)
        errors.append(mse)

    # Finalizar o contador de tempo
    end_time = time.time()
    total_time = end_time - start_time

    # Exibir o tempo total de treinamento
    print(f"Total training time: {total_time:.2f} seconds")

    return np.mean(errors)

# %%
def hyperparameter_optimization(X_train, y_train, model, param_grid):
    results = []
    for params in ParameterGrid(param_grid):
        print(f"Testando a combinação {params}")
        model.set_params(**params)
        mse = time_series_cross_validation(X_train, y_train, model, n_splits=5)

        result = params.copy()
        result["mse"] = mse
        results.append(result)
    return pd.DataFrame(results)

# %%
def final_model_evaluation(X_train, y_train, X_test, y_test, model, best_params):
    """
    Trains the model on the training data and evaluates on the test set.
    Filters out invalid hyperparameters before setting them.
    """
    # Get valid hyperparameters for the model
    valid_params = model.get_params().keys()
    
    # Filter only valid hyperparameters
    filtered_params = {k: v for k, v in best_params.items() if k in valid_params}

    # Set the valid hyperparameters
    model.set_params(**filtered_params)
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions
    predictions = model.predict(X_test)

    # Calculate MSE
    final_mse = mean_squared_error(y_test, predictions)
    
    return final_mse, predictions

# %%
def optimize_and_evaluate(X, y, models_and_params):
    X_train, X_test, y_train, y_test = split_train_test(X, y, train_size=0.8)
    all_results = pd.DataFrame()

    for model_name, model_info in models_and_params.items():
        print(f"Otimizando {model_name}...")
        results_df = hyperparameter_optimization(
            X_train, y_train, model_info["model"], model_info["params"]
        )
        results_df["model"] = model_name

        best_params = results_df.sort_values(by="mse").iloc[0].drop("mse").to_dict()
        final_mse, predictions = final_model_evaluation(
            X_train, y_train, X_test, y_test, model_info["model"], best_params
        )

        print(f"{model_name} - MSE Final no Teste: {final_mse:.4f}")
        results_df["final_test_mse"] = final_mse
        all_results = pd.concat([all_results, results_df], ignore_index=True)

    return all_results

# %%
def optimize_and_evaluate_one_lag(df, models_and_params):
    all_results = pd.DataFrame()

    for column in df.columns:
        print(f"\n🔍 Processing column: {column}")

        # Create lagged feature (lag 1)
        lagged_df = pd.DataFrame({
            f"{column}_lag_1": df[column].shift(1),
            column: df[column]
        }).dropna()

        # Define X and y
        X = lagged_df[[f"{column}_lag_1"]]
        y = lagged_df[column]

        # Split into train and test sets
        X_train, X_test, y_train, y_test = split_train_test(X, y, train_size=0.8)

        # Apply models to each column
        for model_name, model_info in models_and_params.items():
            print(f"⚙️ Optimizing model: {model_name} for {column}")

            # Hyperparameter optimization
            results_df = hyperparameter_optimization(
                X_train, y_train, model_info["model"], model_info["params"]
            )
            results_df["model"] = model_name
            results_df["series"] = column

            # Best hyperparameters
            best_params = results_df.sort_values(by="mse").iloc[0].drop("mse").to_dict()

            # Final evaluation
            final_mse, predictions = final_model_evaluation(
                X_train, y_train, X_test, y_test, model_info["model"], best_params
            )

            print(f"✅ {model_name} for {column} - Final MSE on Test: {final_mse:.4f}")

            # Store results
            results_df["final_test_mse"] = final_mse
            all_results = pd.concat([all_results, results_df], ignore_index=True)

    return all_results

# %%
def evaluate_all_feature_combinations(df, target, exogenous_vars, model, param_grid):
    results = pd.DataFrame()

    # Generate all possible combinations of exogenous variables + lagged target
    all_features = [f"{target}_lag_1"] + exogenous_vars
    feature_combinations = []
    for i in range(1, len(all_features) + 1):
        feature_combinations.extend(combinations(all_features, i))

    # Loop through all feature combinations
    for feature_set in feature_combinations:
        print(f"\n🔍 Evaluating feature set: {feature_set}")
        X = df[list(feature_set)]
        y = df[target]
        
        # Drop rows with NaNs caused by lags
        data = pd.concat([X, y], axis=1).dropna()
        X = data[list(feature_set)]
        y = data[target]

        # Train-test split
        X_train, X_test, y_train, y_test = split_train_test(X, y, train_size=0.8)

        # Optimize hyperparameters for the current feature set
        results_df = hyperparameter_optimization(X_train, y_train, model, param_grid)
        results_df["features"] = [feature_set] * len(results_df)

        # Get best hyperparameters based on MSE
        best_params = results_df.sort_values(by="mse").iloc[0].drop("mse").to_dict()
        final_mse, predictions = final_model_evaluation(
            X_train, y_train, X_test, y_test, model, best_params
        )

        print(f"✅ Features: {feature_set} - Final MSE on Test: {final_mse:.4f}")
        results_df["final_test_mse"] = final_mse

        # Store the results
        results = pd.concat([results, results_df], ignore_index=True)

    return results

# %%
def final_model_evaluation(X_train, y_train, X_test, y_test, model, best_params):
    valid_params = model.get_params().keys()
    
    # Filter valid hyperparameters
    filtered_params = {k: v for k, v in best_params.items() if k in valid_params}

    # Convert floats to integers if necessary
    integer_params = [
        'max_depth', 'max_leaf_nodes', 'min_samples_split', 'min_samples_leaf', 'n_estimators'
    ]
    for param in integer_params:
        if param in filtered_params and isinstance(filtered_params[param], float):
            filtered_params[param] = int(filtered_params[param])

    # Train the model
    model.set_params(**filtered_params)
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    final_mse = mean_squared_error(y_test, predictions)

    return final_mse, predictions

# %% [markdown]
# ## Model evaluation

# %%
def evaluate_performance(predictions, actual):
    '''Evaluates model's performance using MSE, MAE e R²'''
    
    mse = mean_squared_error(actual, predictions)
    mae = mean_absolute_error(actual, predictions)
    
    print(f'MSE: {mse:.4f}')
    print(f'MAE: {mae:.4f}')
    
    return [mse, mae]

# %% [markdown]
# # Getting the data

# %%
criptos = pd.read_csv(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\input_data\cripto_data_consolidated.csv", 
                      delimiter = ";")

# %%
criptos = criptos.drop(criptos.loc[criptos.duplicated() == True].index)

# %%
criptos.columns = ['# timestamp', 'Bitcoin', 'Dogecoin', 'Chainlink', 'Monero', 'Solana']

# %%
criptos = convert_to_date(criptos, '# timestamp')

# %%
features = ['Bitcoin', 'Dogecoin', 'Chainlink', 'Monero', 'Solana']

# %%
criptos
# Out:
#                        # timestamp  Bitcoin  Dogecoin  Chainlink  Monero  \
# date_hour
# 2021-12-02 00:00:00  1638420000000  56897.6  0.205710     24.793  230.85
# 2021-12-02 01:00:00  1638420000000  56651.7  0.205720     24.760  232.06
# 2021-12-02 02:00:00  1638430000000  56819.0  0.206038     24.833  231.54
# 2021-12-02 03:00:00  1638430000000  56947.4  0.220576     24.846  233.80
# 2021-12-02 04:00:00  1638440000000  56682.7  0.214080     24.824  233.75
# ...                            ...      ...       ...        ...     ...
# 2023-12-08 12:00:00  1702050000000  43829.8  0.098340     16.616  173.10
# 2023-12-08 13:00:00  1702050000000  43743.4  0.098370     16.702  173.20
# 2023-12-08 14:00:00  1702060000000  43814.0  0.098590     16.605  173.00
# 2023-12-08 15:00:00  1702060000000  43956.1  0.100260     16.780  172.90
# 2023-12-08 16:00:00  1702070000000  44367.9  0.100610     16.837  174.30
#
#                       Solana       date      hour
# date_hour
# 2021-12-02 00:00:00  223.060 2021-12-02  00:00:00
# 2021-12-02 01:00:00  223.210 2021-12-02  01:00:00
# 2021-12-02 02:00:00  222.975 2021-12-02  02:00:00
# 2021-12-02 03:00:00  227.989 2021-12-02  03:00:00
# 2021-12-02 04:00:00  227.344 2021-12-02  04:00:00
# ...                      ...        ...       ...
# 2023-12-08 12:00:00   72.850 2023-12-08  05:00:00
# 2023-12-08 13:00:00   73.640 2023-12-08  06:00:00
# 2023-12-08 14:00:00   72.770 2023-12-08  07:00:00
# 2023-12-08 15:00:00   72.290 2023-12-08  08:00:00
# 2023-12-08 16:00:00   73.400 2023-12-08  09:00:00
#
# [17674 rows x 8 columns]

# %%
criptos = criptos.drop(['# timestamp', 'date', 'hour'], axis = 1)

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Base 100

# %%
criptos_base_100 = criptos[features] / criptos[features].iloc[0] * 100

# %%
criptos_base_100[features].plot()

plt.tight_layout()

# %%
criptos_base_100.to_excel('plots/criptos_base_100.xlsx')

# %% [markdown]
# ### Standard

# %%
criptos_standard = (criptos[features] - criptos[features].mean()) / criptos[features].std()

# %%
criptos_standard[features].plot()

plt.tight_layout()

# %%
criptos_standard.to_excel('plots/criptos_standard.xlsx')

# %% [markdown]
# ### Standard with Difference

# %%
criptos_standard_diff = criptos_standard[features] - criptos_standard[features].shift(1)
criptos_standard_diff = criptos_standard_diff.dropna()

# %%
criptos_standard_diff[features].plot()

plt.tight_layout()

# %%
criptos_standard_diff.to_excel('plots/criptos_standard_diff.xlsx')

# %%
plt.plot(np.log(criptos.Chainlink))

# %% [markdown]
# ## Correlations

# %% [markdown]
# ### Scatter plots

# %%
sns.pairplot(criptos)

plt.tight_layout()

# %%
criptos.corr()
# Out:
#             Bitcoin  Dogecoin  Chainlink    Monero    Solana
# Bitcoin    1.000000  0.773352   0.859855  0.740375  0.850527
# Dogecoin   0.773352  1.000000   0.864325  0.712206  0.903729
# Chainlink  0.859855  0.864325   1.000000  0.662974  0.926769
# Monero     0.740375  0.712206   0.662974  1.000000  0.704671
# Solana     0.850527  0.903729   0.926769  0.704671  1.000000

# %%
criptos_diff = (criptos - criptos.shift(1)) / criptos.shift(1)

# %%
criptos_diff = criptos_diff.dropna()

# %%
sns.pairplot(criptos_diff)

plt.tight_layout()

# %%
criptos_diff.corr()
# Out:
#             Bitcoin  Dogecoin  Chainlink    Monero    Solana
# Bitcoin    1.000000  0.642423   0.747104  0.629627  0.692318
# Dogecoin   0.642423  1.000000   0.649148  0.527454  0.596929
# Chainlink  0.747104  0.649148   1.000000  0.616830  0.693762
# Monero     0.629627  0.527454   0.616830  1.000000  0.541704
# Solana     0.692318  0.596929   0.693762  0.541704  1.000000

# %% [markdown]
# ## Correlations with lags

# %%
series_dict = {
    'Bitcoin': criptos['Bitcoin'],
    'DogeCoin': criptos['Dogecoin'],
    'Chainlink': criptos['Chainlink'],
    'Monero': criptos['Monero'],
    'Solana': criptos['Solana']
}

# %%
series_dict_diff = {
    'Bitcoin': criptos_diff['Bitcoin'],
    'DogeCoin': criptos_diff['Dogecoin'],
    'Chainlink': criptos_diff['Chainlink'],
    'Monero': criptos_diff['Monero'],
    'Solana': criptos_diff['Solana']
}

# %% [markdown]
# ### Bitcoin

# %%
correlation_with_lags(criptos['Bitcoin'], series_dict, max_lag = 200)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      1.000000    0.999796    0.999591    0.999384    0.999179
# DogeCoin     0.773352    0.772948    0.772542    0.772138    0.771744
# Chainlink    0.859855    0.859577    0.859291    0.859001    0.858718
# Monero       0.740375    0.739938    0.739496    0.739046    0.738598
# Solana       0.850527    0.850192    0.849851    0.849505    0.849154
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  ...  \
# Bitcoin      0.998970    0.998758    0.998539    0.998324    0.998105  ...
# DogeCoin     0.771343    0.770939    0.770527    0.770125    0.769716  ...
# Chainlink    0.858428    0.858130    0.857827    0.857531    0.857230  ...
# Monero       0.738125    0.737630    0.737108    0.736605    0.736079  ...
# Solana       0.848802    0.848447    0.848092    0.847735    0.847372  ...
#
#            corr_lag_191  corr_lag_192  corr_lag_193  corr_lag_194  \
# Bitcoin        0.957092      0.956889      0.956680      0.956482
# DogeCoin       0.707602      0.707330      0.707053      0.706793
# Chainlink      0.813229      0.813012      0.812793      0.812588
# Monero         0.646353      0.645953      0.645551      0.645162
# Solana         0.795886      0.795630      0.795369      0.795120
#
#            corr_lag_195  corr_lag_196  corr_lag_197  corr_lag_198  \
# Bitcoin        0.956283      0.956088      0.955888      0.955687
# DogeCoin       0.706537      0.706281      0.706023      0.705763
# Chainlink      0.812377      0.812166      0.811954      0.811741
# Monero         0.644761      0.644376      0.643984      0.643594
# Solana         0.794872      0.794622      0.794368      0.794111
#
#            corr_lag_199  corr_lag_200
# Bitcoin        0.955486      0.955287
# DogeCoin       0.705500      0.705243
# Chainlink      0.811522      0.811299
# Monero         0.643217      0.642836
# Solana         0.793847      0.793577
#
# [5 rows x 201 columns]

# %%
correlation_with_lags(criptos_diff['Bitcoin'], series_dict_diff, max_lag = 200)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      1.000000   -0.003733    0.000173   -0.004536   -0.000257
# DogeCoin     0.642423    0.001426   -0.000252   -0.013804    0.012619
# Chainlink    0.747104    0.009485    0.002589   -0.015014    0.014684
# Monero       0.629627    0.006409    0.005200   -0.004172    0.015500
# Solana       0.692318    0.028377    0.009252    0.004515    0.004702
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  ...  \
# Bitcoin      0.000519    0.012657   -0.018011    0.011765    0.005719  ...
# DogeCoin     0.004808   -0.001831   -0.008705    0.011025    0.003153  ...
# Chainlink    0.004494    0.009856   -0.020517    0.015830   -0.000942  ...
# Monero       0.017445    0.014995   -0.018524    0.022130    0.001558  ...
# Solana      -0.005848    0.003704   -0.006951    0.019018    0.013510  ...
#
#            corr_lag_191  corr_lag_192  corr_lag_193  corr_lag_194  \
# Bitcoin        0.002070      0.000957     -0.005056      0.008013
# DogeCoin       0.000462     -0.003583     -0.011032      0.003923
# Chainlink     -0.008398     -0.004807     -0.009943      0.012847
# Monero         0.004709     -0.005480      0.000155      0.009044
# Solana        -0.003068     -0.007441     -0.013614      0.008659
#
#            corr_lag_195  corr_lag_196  corr_lag_197  corr_lag_198  \
# Bitcoin       -0.017114      0.007069     -0.005061     -0.002618
# DogeCoin      -0.017755     -0.007754      0.000261     -0.007917
# Chainlink     -0.015309     -0.001319     -0.004635      0.001045
# Monero        -0.018353      0.002830     -0.003930     -0.011514
# Solana        -0.016239     -0.005528     -0.004071     -0.002011
#
#            corr_lag_199  corr_lag_200
# Bitcoin        0.000667     -0.001082
# DogeCoin       0.000915     -0.011595
# Chainlink      0.008591     -0.004273
# Monero         0.006550     -0.001196
# Solana         0.005579      0.001376
#
# [5 rows x 201 columns]

# %% [markdown]
# ### Dogecoin

# %%
correlation_with_lags(criptos['Dogecoin'], series_dict, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.773352    0.773264    0.773183    0.773106    0.773024
# DogeCoin     1.000000    0.999477    0.998950    0.998448    0.997981
# Chainlink    0.864325    0.864252    0.864180    0.864108    0.864053
# Monero       0.712206    0.711810    0.711442    0.711053    0.710698
# Solana       0.903729    0.903578    0.903429    0.903276    0.903104
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin      0.772940    0.772853    0.772771    0.772692    0.772611
# DogeCoin     0.997509    0.997033    0.996542    0.996075    0.995612
# Chainlink    0.863976    0.863894    0.863825    0.863762    0.863690
# Monero       0.710308    0.709902    0.709501    0.709127    0.708723
# Solana       0.902925    0.902741    0.902570    0.902400    0.902230
#
#            corr_lag_10
# Bitcoin       0.772523
# DogeCoin      0.995142
# Chainlink     0.863615
# Monero        0.708308
# Solana        0.902057

# %%
correlation_with_lags(criptos_diff['Dogecoin'], series_dict_diff, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.642423   -0.018804   -0.011399   -0.010389   -0.001807
# DogeCoin     1.000000   -0.009135   -0.027378   -0.022066    0.004466
# Chainlink    0.649148   -0.011988   -0.009937   -0.023681    0.016958
# Monero       0.527454   -0.024286    0.005853   -0.018737    0.013381
# Solana       0.596929    0.013137   -0.000206   -0.007218    0.007438
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin     -0.006349   -0.006462   -0.016330    0.026028    0.004753
# DogeCoin    -0.002390    0.000795   -0.009999    0.022332    0.002008
# Chainlink   -0.001796   -0.008036   -0.017694    0.022483    0.002045
# Monero       0.005843   -0.004276   -0.022148    0.032144    0.001924
# Solana      -0.017178   -0.005995   -0.007383    0.032174    0.004984
#
#            corr_lag_10
# Bitcoin      -0.003502
# DogeCoin     -0.012891
# Chainlink    -0.008868
# Monero       -0.002207
# Solana       -0.003185

# %% [markdown]
# ### ChainLink

# %%
correlation_with_lags(criptos['Chainlink'], series_dict, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.859855    0.859671    0.859490    0.859308    0.859136
# DogeCoin     0.864325    0.863888    0.863444    0.863007    0.862586
# Chainlink    1.000000    0.999685    0.999365    0.999041    0.998738
# Monero       0.662974    0.662576    0.662185    0.661793    0.661418
# Solana       0.926769    0.926515    0.926251    0.925985    0.925721
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin      0.858966    0.858790    0.858613    0.858448    0.858279
# DogeCoin     0.862170    0.861747    0.861323    0.860922    0.860514
# Chainlink    0.998427    0.998096    0.997769    0.997461    0.997143
# Monero       0.661031    0.660634    0.660223    0.659843    0.659433
# Solana       0.925452    0.925177    0.924904    0.924633    0.924363
#
#            corr_lag_10
# Bitcoin       0.858106
# DogeCoin      0.860104
# Chainlink     0.996832
# Monero        0.659026
# Solana        0.924091

# %%
correlation_with_lags(criptos_diff['Chainlink'], series_dict_diff, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.747104   -0.015611   -0.014989   -0.014699   -0.007794
# DogeCoin     0.649148   -0.009622   -0.016179   -0.019668   -0.000157
# Chainlink    1.000000   -0.005697   -0.003423   -0.021367    0.014553
# Monero       0.616830   -0.017296   -0.004394   -0.015142    0.013064
# Solana       0.693762    0.022054   -0.006490   -0.009371    0.014398
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin     -0.009609   -0.004886   -0.020336    0.017491   -0.001535
# DogeCoin    -0.006882   -0.011917   -0.017542    0.019704    0.002000
# Chainlink   -0.003871    0.000240   -0.028525    0.026019   -0.006790
# Monero      -0.004713    0.001952   -0.026943    0.032584   -0.005431
# Solana      -0.024269   -0.001372   -0.015934    0.022829    0.002573
#
#            corr_lag_10
# Bitcoin      -0.007967
# DogeCoin     -0.006260
# Chainlink    -0.014832
# Monero       -0.007300
# Solana       -0.000783

# %% [markdown]
# ### Monero

# %%
correlation_with_lags(criptos['Monero'], series_dict, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.740375    0.740103    0.739848    0.739619    0.739396
# DogeCoin     0.712206    0.711684    0.711198    0.710737    0.710272
# Chainlink    0.662974    0.662537    0.662120    0.661724    0.661353
# Monero       1.000000    0.998700    0.997452    0.996239    0.995083
# Solana       0.704671    0.704338    0.704016    0.703713    0.703408
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin      0.739168    0.738935    0.738696    0.738465    0.738221
# DogeCoin     0.709804    0.709325    0.708849    0.708374    0.707866
# Chainlink    0.660967    0.660575    0.660184    0.659805    0.659403
# Monero       0.993895    0.992711    0.991511    0.990341    0.989083
# Solana       0.703093    0.702770    0.702445    0.702119    0.701779
#
#            corr_lag_10
# Bitcoin       0.737953
# DogeCoin      0.707336
# Chainlink     0.658986
# Monero        0.987866
# Solana        0.701420

# %%
correlation_with_lags(criptos_diff['Monero'], series_dict_diff, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.629627   -0.016692   -0.026725   -0.008768   -0.002868
# DogeCoin     0.527454   -0.027116   -0.016472   -0.009416   -0.000091
# Chainlink    0.616830   -0.023531   -0.021477   -0.025606    0.007618
# Monero       1.000000   -0.021862   -0.016745   -0.024176    0.007677
# Solana       0.541704   -0.007891   -0.013466   -0.012127    0.005173
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin     -0.004585    0.001503   -0.014077    0.021158    0.009347
# DogeCoin    -0.002052   -0.009712   -0.002316    0.021491    0.001557
# Chainlink   -0.004208   -0.004962   -0.014128    0.020684   -0.000452
# Monero      -0.003431    0.002263   -0.018400    0.032589   -0.020010
# Solana      -0.017355    0.000776   -0.010620    0.022285    0.006257
#
#            corr_lag_10
# Bitcoin       0.013265
# DogeCoin      0.000053
# Chainlink     0.004510
# Monero        0.014562
# Solana        0.007855

# %% [markdown]
# ### Solana

# %%
correlation_with_lags(criptos['Solana'], series_dict, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.850527    0.850557    0.850591    0.850626    0.850663
# DogeCoin     0.903729    0.903509    0.903288    0.903076    0.902867
# Chainlink    0.926769    0.926707    0.926643    0.926583    0.926529
# Monero       0.704671    0.704418    0.704173    0.703926    0.703678
# Solana       1.000000    0.999851    0.999702    0.999556    0.999405
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin      0.850704    0.850741    0.850775    0.850810    0.850841
# DogeCoin     0.902655    0.902447    0.902235    0.902032    0.901822
# Chainlink    0.926472    0.926416    0.926361    0.926314    0.926249
# Monero       0.703423    0.703162    0.702891    0.702630    0.702341
# Solana       0.999255    0.999106    0.998960    0.998816    0.998668
#
#            corr_lag_10
# Bitcoin       0.850880
# DogeCoin      0.901621
# Chainlink     0.926195
# Monero        0.702072
# Solana        0.998524

# %%
correlation_with_lags(criptos_diff['Solana'], series_dict_diff, max_lag = 10)
# Out:
#            corr_lag_0  corr_lag_1  corr_lag_2  corr_lag_3  corr_lag_4  \
# Bitcoin      0.692318   -0.026598   -0.007677   -0.011101   -0.007664
# DogeCoin     0.596929   -0.024874   -0.008575   -0.012839   -0.000356
# Chainlink    0.693762   -0.014820   -0.007720   -0.018747    0.012806
# Monero       0.541704   -0.023192    0.006556   -0.012675    0.008142
# Solana       1.000000    0.000167   -0.022333   -0.004472   -0.008132
#
#            corr_lag_5  corr_lag_6  corr_lag_7  corr_lag_8  corr_lag_9  \
# Bitcoin      0.001566   -0.001947   -0.018151    0.022317   -0.012753
# DogeCoin    -0.011602   -0.018774   -0.006263    0.025344   -0.016019
# Chainlink   -0.003890   -0.009141   -0.019264    0.029281   -0.016718
# Monero      -0.001526   -0.013684   -0.017499    0.037815   -0.024698
# Solana      -0.013171   -0.018176   -0.025782    0.056234    0.008493
#
#            corr_lag_10
# Bitcoin       0.004440
# DogeCoin      0.006944
# Chainlink     0.005283
# Monero        0.013590
# Solana       -0.001630

# %% [markdown]
# ## AR model

# %% [markdown]
# ### Stationarity

# %%
criptos.duplicated().sum()
# Out:
# np.int64(3)

# %% [markdown]
# #### Original series

# %%
check_stationarity(criptos['Bitcoin'])
# Out:
# ADF Statistic: -2.6381900759604924
# p-value: 0.08535820075503625
# A série não é estacionária (p > 0.05)

# %% [markdown]
# #### Diff series

# %%
check_stationarity(criptos_diff['Bitcoin'])
# Out:
# ADF Statistic: -23.927826818441524
# p-value: 0.0
# A série é estacionária (p <= 0.05)

# %% [markdown]
# ## AR Models
#
# First, we are going to apply the AR model to every time series with itself

# %% [markdown]
# ## Autocorrelation

# %%
N_LAGS = 20

# %% [markdown]
# ### ACF

# %%
plot_autocorrelation(df = criptos_diff, n_lags = N_LAGS, autocorrelation_function = 'ACF')

# %% [markdown]
# ### PACF

# %%
plot_autocorrelation(df = criptos_diff, n_lags = N_LAGS, autocorrelation_function = 'PACF')

# %% [markdown]
# ## Creating the models

# %%
LAGS = [1]
STARTING_POINT = 0.8

# %%
performance, residuals = fit_ar_model(criptos_diff, starting_point_percent = STARTING_POINT, lags_list = LAGS)
# Out:
# Treinando para 1 lags
# Treinando com a variável: Bitcoin
# Treinando modelo AR com 1 lags
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# MSE: 0.0000
# MAE: 0.0023
# MSE: 0.0000
# MAE: 0.0035
# Treinando com a variável: Dogecoin
# Treinando modelo AR com 1 lags
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# MSE: 0.0000
# MAE: 0.0042
# MSE: 0.0001
# MAE: 0.0062
# Treinando com a variável: Chainlink
# Treinando modelo AR com 1 lags
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# MSE: 0.0001
# MAE: 0.0056
# MSE: 0.0001
# MAE: 0.0084
# Treinando com a variável: Monero
# Treinando modelo AR com 1 lags
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# MSE: 0.0000
# MAE: 0.0031
# MSE: 0.0000
# MAE: 0.0046
# Treinando com a variável: Solana
# Treinando modelo AR com 1 lags
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Caio\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# MSE: 0.0001
# MAE: 0.0062
# MSE: 0.0002
# MAE: 0.0092

# %%
performance.to_excel(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\output_data\ar_performance_table.xlsx")

# %%
performance
# Out:
#                            MSE       MAE
# Variable        Lags
# Bitcoin         1     0.000015  0.002280
# Naive_Bitcoin   1     0.000033  0.003503
# Dogecoin        1     0.000046  0.004165
# Naive_Dogecoin  1     0.000096  0.006202
# Chainlink       1     0.000071  0.005637
# Naive_Chainlink 1     0.000145  0.008377
# Monero          1     0.000019  0.003054
# Naive_Monero    1     0.000041  0.004565
# Solana          1     0.000089  0.006219
# Naive_Solana    1     0.000181  0.009236

# %%
residuals
# Out:
# Variable              Bitcoin  Dogecoin Chainlink    Monero    Solana
# Lags                        1         1         1         1         1
# date_hour
# 2023-07-14 10:00:00 -0.001330 -0.000647  0.002319  0.006853 -0.005416
# 2023-07-14 11:00:00  0.001815 -0.026154 -0.005660  0.000447 -0.003939
# 2023-07-14 12:00:00  0.000994  0.013188  0.008348  0.009430  0.025374
# 2023-07-14 13:00:00  0.017147  0.027969  0.018621  0.016740  0.011516
# 2023-07-14 14:00:00  0.019151  0.033155  0.028205  0.016339  0.042167
# ...                       ...       ...       ...       ...       ...
# 2023-12-08 12:00:00 -0.001385 -0.004534  0.004814 -0.001016 -0.012640
# 2023-12-08 13:00:00  0.001969 -0.000338 -0.005122 -0.000588 -0.010829
# 2023-12-08 14:00:00 -0.001604 -0.002230  0.005806  0.001157  0.011830
# 2023-12-08 15:00:00 -0.003247 -0.016950 -0.010479  0.000618  0.006607
# 2023-12-08 16:00:00 -0.009378 -0.003635 -0.003430 -0.008070 -0.015343
#
# [3535 rows x 5 columns]

# %% [markdown]
# ## Adding exogenous variables

# %%
performance_exog, residuals_exog = fit_ar_model_exog(df = criptos_diff, target_column = 'Bitcoin', starting_point_percent = STARTING_POINT, lags_list = LAGS)
# Out:
# Treinando para 1 lags
# Treinando com variáveis exógenas: ('Dogecoin',)
# Treinando modelo AR com variáveis exógenas e lags
# Modelo ajustado
# Predição passo 1
# Predição passo 2
# Predição passo 3
# Predição passo 4
# Predição passo 5
# Predição passo 6
# Predição passo 7
# Predição passo 8
# Predição passo 9
# Predição passo 10
# Predição passo 11
# Predição passo 12
# Predição passo 13
# Predição passo 14
# Predição passo 15
# Predição passo 16
# Predição passo 17
# Predição passo 18
# Predição passo 19
# Predição passo 20
# Predição passo 21
# Predição passo 22
# Predição passo 23
# Predição passo 24
# Predição passo 25
# Predição passo 26
# Predição passo 27
# Predição passo 28
# Predição passo 29
# Predição passo 30
# Predição passo 31
# Predição passo 32
# Predição passo 33
# Predição passo 34
# Predição passo 35
# Predição passo 36
# Predição passo 37
# Predição passo 38
# Predição passo 39
# Predição passo 40
# Predição passo 41
# Predição passo 42
# Predição passo 43
# Predição passo 44
# Predição passo 45
# Predição passo 46
# Predição passo 47
# Predição passo 48
# Predição passo 49
# Predição passo 50
# Predição passo 51
# Predição passo 52
# Predição passo 53
# Predição passo 54
# Predição passo 55
# Predição passo 56
# Predição passo 57
# Predição passo 58
# Predição passo 59
# Predição passo 60
# Predição passo 61
# Predição passo 62
# Predição passo 63
# Predição passo 64
# Predição passo 65
# Predição passo 66
# Predição passo 67
# Predição passo 68
# Predição passo 69
# Predição passo 70
# Predição passo 71
# Predição passo 72
# Predição passo 73
# Predição passo 74
# Predição passo 75
# Predição passo 76
# Predição passo 77
# Predição passo 78
# Predição passo 79
# Predição passo 80
# Predição passo 81
# Predição passo 82
# Predição passo 83
# Predição passo 84
# Predição passo 85
# Predição passo 86
# Predição passo 87
# Predição passo 88
# Predição passo 89
# Predição passo 90
# Predição passo 91
# Predição passo 92
# Predição passo 93
# Predição passo 94
# Predição passo 95
# Predição passo 96
# Predição passo 97
# Predição passo 98
# Predição passo 99
# Predição passo 100
# Predição passo 101
# Predição passo 102
# Predição passo 103
# Predição passo 104
# Predição passo 105
# Predição passo 106
# Predição passo 107
# Predição passo 108
# Predição passo 109
# Predição passo 110
# Predição passo 111
# Predição passo 112
# Predição passo 113
# Predição passo 114
# Predição passo 115
# Predição passo 116
# Predição passo 117
# Predição passo 118
# Predição passo 119
# Predição passo 120
# Predição passo 121
# Predição passo 122
# Predição passo 123
# Predição passo 124
# Predição passo 125
# Predição passo 126
# Predição passo 127
# Predição passo 128
# Predição passo 129
# Predição passo 130
# Predição passo 131
# Predição passo 132
# Predição passo 133
# Predição passo 134
# Predição passo 135
# Predição passo 136
# Predição passo 137
# Predição passo 138
# Predição passo 139
# Predição passo 140
# Predição passo 141
# Predição passo 142
# Predição passo 143
# Predição passo 144
# Predição passo 145
# Predição passo 146
# Predição passo 147
# Predição passo 148
# Predição passo 149
# Predição passo 150
# Predição passo 151
# Predição passo 152
# Predição passo 153
# Predição passo 154
# Predição passo 155
# Predição passo 156
# Predição passo 157
# Predição passo 158
# Predição passo 159
# Predição passo 160
# Predição passo 161
# Predição passo 162
# Predição passo 163
# Predição passo 164
# Predição passo 165
# Predição passo 166
# Predição passo 167
# Predição passo 168
# Predição passo 169
# Predição passo 170
# Predição passo 171
# Predição passo 172
# Predição passo 173
# Predição passo 174
# Predição passo 175
# Predição passo 176
# Predição passo 177
# Predição passo 178
# Predição passo 179
# Predição passo 180
# Predição passo 181
# Predição passo 182
# Predição passo 183
# Predição passo 184
# Predição passo 185
# Predição passo 186
# Predição passo 187
# Predição passo 188
# Predição passo 189
# Predição passo 190
# Predição passo 191
# Predição passo 192
# Predição passo 193
# Predição passo 194
# Predição passo 195
# Predição passo 196
# Predição passo 197
# Predição passo 198
# Predição passo 199
# Predição passo 200
# Predição passo 201
# Predição passo 202
# Predição passo 203
# Predição passo 204
# Predição passo 205
# Predição passo 206
# Predição passo 207
# Predição passo 208
# Predição passo 209
# Predição passo 210
# Predição passo 211
# Predição passo 212
# Predição passo 213
# Predição passo 214
# Predição passo 215
# Predição passo 216
# Predição passo 217
# Predição passo 218
# Predição passo 219
# Predição passo 220
# Predição passo 221
# Predição passo 222
# Predição passo 223
# Predição passo 224
# Predição passo 225
# Predição passo 226
# Predição passo 227
# Predição passo 228
# Predição passo 229
# Predição passo 230
# Predição passo 231
# Predição passo 232
# Predição passo 233
# Predição passo 234
# Predição passo 235
# Predição passo 236
# Predição passo 237
# Predição passo 238
# Predição passo 239
# Predição passo 240
# Predição passo 241
# Predição passo 242
# Predição passo 243
# Predição passo 244
# Predição passo 245
# Predição passo 246
# Predição passo 247
# Predição passo 248
# Predição passo 249
# Predição passo 250
# Predição passo 251
# Predição passo 252
# Predição passo 253
# Predição passo 254
# Predição passo 255
# Predição passo 256
# Predição passo 257
# Predição passo 258
# Predição passo 259
# Predição passo 260
# Predição passo 261
# Predição passo 262
# Predição passo 263
# Predição passo 264
# Predição passo 265
# Predição passo 266
# Predição passo 267
# Predição passo 268
# Predição passo 269
# Predição passo 270
# Predição passo 271
# Predição passo 272
# Predição passo 273
# Predição passo 274
# Predição passo 275
# Predição passo 276
# Predição passo 277
# Predição passo 278
# Predição passo 279
# Predição passo 280
# Predição passo 281
# Predição passo 282
# Predição passo 283
# Predição passo 284
# Predição passo 285
# Predição passo 286
# Predição passo 287
# Predição passo 288
# Predição passo 289
# Predição passo 290
# Predição passo 291
# Predição passo 292
# Predição passo 293
# Predição passo 294
# Predição passo 295
# Predição passo 296
# Predição passo 297
# Predição passo 298
# Predição passo 299
# Predição passo 300
# Predição passo 301
# Predição passo 302
# Predição passo 303
# Predição passo 304
# Predição passo 305
# Predição passo 306
# Predição passo 307
# Predição passo 308
# Predição passo 309
# Predição passo 310
# Predição passo 311
# Predição passo 312
# Predição passo 313
# Predição passo 314
# Predição passo 315
# Predição passo 316
# Predição passo 317
# Predição passo 318
# Predição passo 319
# Predição passo 320
# Predição passo 321
# Predição passo 322
# Predição passo 323
# Predição passo 324
# Predição passo 325
# Predição passo 326
# Predição passo 327
# Predição passo 328
# Predição passo 329
# Predição passo 330
# Predição passo 331
# Predição passo 332
# Predição passo 333
# Predição passo 334
# Predição passo 335
# Predição passo 336
# Predição passo 337
# Predição passo 338
# Predição passo 339
# Predição passo 340
# Predição passo 341
# Predição passo 342
# Predição passo 343
# Predição passo 344
# Predição passo 345
# Predição passo 346
# Predição passo 347
# Predição passo 348
# Predição passo 349
# Predição passo 350
# Predição passo 351
# Predição passo 352
# Predição passo 353
# Predição passo 354
# Predição passo 355
# Predição passo 356
# Predição passo 357
# Predição passo 358
# Predição passo 359
# Predição passo 360
# Predição passo 361
# Predição passo 362
# Predição passo 363
# Predição passo 364
# Predição passo 365
# Predição passo 366
# Predição passo 367
# Predição passo 368
# Predição passo 369
# Predição passo 370
# Predição passo 371
# Predição passo 372
# Predição passo 373
# Predição passo 374
# Predição passo 375
# Predição passo 376
# Predição passo 377
# Predição passo 378
# Predição passo 379
# Predição passo 380
# Predição passo 381
# Predição passo 382
# Predição passo 383
# Predição passo 384
# Predição passo 385
# Predição passo 386
# Predição passo 387
# Predição passo 388
# Predição passo 389
# Predição passo 390
# Predição passo 391
# Predição passo 392
# Predição passo 393
# Predição passo 394
# Predição passo 395
# Predição passo 396
# Predição passo 397
# Predição passo 398
# Predição passo 399
# Predição passo 400
# Predição passo 401
# Predição passo 402
# Predição passo 403
# Predição passo 404
# Predição passo 405
# Predição passo 406
# Predição passo 407
# Predição passo 408
# Predição passo 409
# Predição passo 410
# Predição passo 411
# Predição passo 412
# Predição passo 413
# Predição passo 414
# Predição passo 415
# Predição passo 416
# Predição passo 417
# Predição passo 418
# Predição passo 419
# Predição passo 420
# Predição passo 421
# Predição passo 422
# Predição passo 423
# Predição passo 424
# Predição passo 425
# Predição passo 426
# Predição passo 427
# Predição passo 428
# Predição passo 429
# Predição passo 430
# Predição passo 431
# Predição passo 432
# Predição passo 433
# Predição passo 434
# Predição passo 435
# Predição passo 436
# Predição passo 437
# Predição passo 438
# Predição passo 439
# Predição passo 440
# Predição passo 441
# Predição passo 442
# Predição passo 443
# Predição passo 444
# Predição passo 445
# Predição passo 446
# Predição passo 447
# Predição passo 448
# Predição passo 449
# Predição passo 450
# Predição passo 451
# Predição passo 452
# Predição passo 453
# Predição passo 454
# Predição passo 455
# Predição passo 456
# Predição passo 457
# Predição passo 458
# Predição passo 459
# Predição passo 460
# Predição passo 461
# Predição passo 462
# Predição passo 463
# Predição passo 464
# Predição passo 465
# Predição passo 466
# Predição passo 467
# Predição passo 468
# Predição passo 469
# Predição passo 470
# Predição passo 471
# Predição passo 472
# Predição passo 473
# Predição passo 474
# Predição passo 475
# Predição passo 476
# Predição passo 477
# Predição passo 478
# Predição passo 479
# Predição passo 480
# Predição passo 481
# Predição passo 482
# Predição passo 483
# Predição passo 484
# Predição passo 485
# Predição passo 486
# Predição passo 487
# Predição passo 488
# Predição passo 489
# Predição passo 490
# Predição passo 491
# Predição passo 492
# Predição passo 493
# Predição passo 494
# Predição passo 495
# Predição passo 496
# Predição passo 497
# Predição passo 498
# Predição passo 499
# Predição passo 500
# Predição passo 501
# Predição passo 502
# Predição passo 503
# Predição passo 504
# Predição passo 505
# Predição passo 506
# Predição passo 507
# Predição passo 508
# Predição passo 509
# Predição passo 510
# Predição passo 511
# Predição passo 512
# Predição passo 513
# Predição passo 514
# Predição passo 515
# Predição passo 516
# Predição passo 517
# Predição passo 518
# Predição passo 519
# Predição passo 520
# Predição passo 521
# Predição passo 522
# Predição passo 523
# Predição passo 524
# Predição passo 525
# Predição passo 526
# Predição passo 527
# Predição passo 528
# Predição passo 529
# Predição passo 530
# Predição passo 531
# Predição passo 532
# Predição passo 533
# Predição passo 534
# Predição passo 535
# Predição passo 536
# Predição passo 537
# Predição passo 538
# Predição passo 539
# Predição passo 540
# Predição passo 541
# Predição passo 542
# Predição passo 543
# Predição passo 544
# Predição passo 545
# Predição passo 546
# Predição passo 547
# Predição passo 548
# Predição passo 549
# Predição passo 550
# Predição passo 551
# Predição passo 552
# Predição passo 553
# Predição passo 554
# Predição passo 555
# Predição passo 556
# Predição passo 557
# Predição passo 558
# Predição passo 559
# Predição passo 560
# Predição passo 561
# Predição passo 562
# Predição passo 563
# Predição passo 564
# Predição passo 565
# Predição passo 566
# Predição passo 567
# Predição passo 568
# Predição passo 569
# Predição passo 570
# Predição passo 571
# Predição passo 572
# Predição passo 573
# Predição passo 574
# Predição passo 575
# Predição passo 576
# Predição passo 577
# Predição passo 578
# Predição passo 579
# Predição passo 580
# Predição passo 581
# Predição passo 582
# Predição passo 583
# Predição passo 584
# Predição passo 585
# Predição passo 586
# Predição passo 587
# Predição passo 588
# Predição passo 589
# Predição passo 590
# Predição passo 591
# Predição passo 592
# Predição passo 593
# Predição passo 594
# Predição passo 595
# Predição passo 596
# Predição passo 597
# Predição passo 598
# Predição passo 599
# Predição passo 600
# Predição passo 601
# Predição passo 602
# Predição passo 603
# Predição passo 604
# Predição passo 605
# Predição passo 606
# Predição passo 607
# Predição passo 608
# Predição passo 609
# Predição passo 610
# Predição passo 611
# Predição passo 612
# Predição passo 613
# Predição passo 614
# Predição passo 615
# Predição passo 616
# Predição passo 617
# Predição passo 618
# Predição passo 619
# Predição passo 620
# Predição passo 621
# Predição passo 622
# Predição passo 623
# Predição passo 624
# Predição passo 625
# Predição passo 626
# Predição passo 627
# Predição passo 628
# Predição passo 629
# Predição passo 630
# Predição passo 631
# Predição passo 632
# Predição passo 633
# Predição passo 634
# Predição passo 635
# Predição passo 636
# Predição passo 637
# Predição passo 638
# Predição passo 639
# Predição passo 640
# Predição passo 641
# Predição passo 642
# Predição passo 643
# Predição passo 644
# Predição passo 645
# Predição passo 646
# Predição passo 647
# Predição passo 648
# Predição passo 649
# Predição passo 650
# Predição passo 651
# Predição passo 652
# Predição passo 653
# Predição passo 654
# Predição passo 655
# Predição passo 656
# Predição passo 657
# Predição passo 658
# Predição passo 659
# Predição passo 660
# Predição passo 661
# Predição passo 662
# Predição passo 663
# Predição passo 664
# Predição passo 665
# Predição passo 666
# Predição passo 667
# Predição passo 668
# Predição passo 669
# Predição passo 670
# Predição passo 671
# Predição passo 672
# Predição passo 673
# Predição passo 674
# Predição passo 675
# Predição passo 676
# Predição passo 677
# Predição passo 678
# Predição passo 679
# Predição passo 680
# Predição passo 681
# Predição passo 682
# Predição passo 683
# Predição passo 684
# Predição passo 685
# Predição passo 686
# Predição passo 687
# Predição passo 688
# Predição passo 689
# Predição passo 690
# Predição passo 691
# Predição passo 692
# Predição passo 693
# Predição passo 694
# Predição passo 695
# Predição passo 696
# Predição passo 697
# Predição passo 698
# Predição passo 699
# Predição passo 700
# Predição passo 701
# Predição passo 702
# Predição passo 703
# Predição passo 704
# Predição passo 705
# Predição passo 706
# Predição passo 707
# Predição passo 708
# Predição passo 709
# Predição passo 710
# Predição passo 711
# Predição passo 712
# Predição passo 713
# Predição passo 714
# Predição passo 715
# Predição passo 716
# Predição passo 717
# Predição passo 718
# Predição passo 719
# Predição passo 720
# Predição passo 721
# Predição passo 722
# Predição passo 723
# Predição passo 724
# Predição passo 725
# Predição passo 726
# Predição passo 727
# Predição passo 728
# Predição passo 729
# Predição passo 730
# Predição passo 731
# Predição passo 732
# Predição passo 733
# Predição passo 734
# Predição passo 735
# Predição passo 736
# Predição passo 737
# Predição passo 738
# Predição passo 739
# Predição passo 740
# Predição passo 741
# Predição passo 742
# Predição passo 743
# Predição passo 744
# Predição passo 745
# Predição passo 746
# Predição passo 747
# Predição passo 748
# Predição passo 749
# Predição passo 750
# Predição passo 751
# Predição passo 752
# Predição passo 753
# Predição passo 754
# Predição passo 755
# Predição passo 756
# Predição passo 757
# Predição passo 758
# Predição passo 759
# Predição passo 760
# Predição passo 761
# Predição passo 762
# Predição passo 763
# Predição passo 764
# Predição passo 765
# Predição passo 766
# Predição passo 767
# Predição passo 768
# Predição passo 769
# Predição passo 770
# Predição passo 771
# Predição passo 772
# Predição passo 773
# Predição passo 774
# Predição passo 775
# Predição passo 776
# Predição passo 777
# Predição passo 778
# Predição passo 779
# Predição passo 780
# Predição passo 781
# Predição passo 782
# Predição passo 783
# Predição passo 784
# Predição passo 785
# Predição passo 786
# Predição passo 787
# Predição passo 788
# Predição passo 789
# Predição passo 790
# Predição passo 791
# Predição passo 792
# Predição passo 793
# Predição passo 794
# Predição passo 795
# Predição passo 796
# Predição passo 797
# Predição passo 798
# Predição passo 799
# Predição passo 800
# Predição passo 801
# Predição passo 802
# Predição passo 803
# Predição passo 804
# Predição passo 805
# Predição passo 806
# Predição passo 807
# Predição passo 808
# Predição passo 809
# Predição passo 810
# Predição passo 811
# Predição passo 812
# Predição passo 813
# Predição passo 814
# Predição passo 815
# Predição passo 816
# Predição passo 817
# Predição passo 818
# Predição passo 819
# Predição passo 820
# Predição passo 821
# Predição passo 822
# Predição passo 823
# Predição passo 824
# Predição passo 825
# Predição passo 826
# Predição passo 827
# Predição passo 828
# Predição passo 829
# Predição passo 830
# Predição passo 831
# Predição passo 832
# Predição passo 833
# Predição passo 834
# Predição passo 835
# Predição passo 836
# Predição passo 837
# Predição passo 838
# Predição passo 839
# Predição passo 840
# Predição passo 841
# Predição passo 842
# Predição passo 843
# Predição passo 844
# Predição passo 845
# Predição passo 846
# Predição passo 847
# Predição passo 848
# Predição passo 849
# Predição passo 850
# Predição passo 851
# Predição passo 852
# Predição passo 853
# Predição passo 854
# Predição passo 855
# Predição passo 856
# Predição passo 857
# Predição passo 858
# Predição passo 859
# Predição passo 860
# Predição passo 861
# Predição passo 862
# Predição passo 863
# Predição passo 864
# Predição passo 865
# Predição passo 866
# Predição passo 867
# Predição passo 868
# Predição passo 869
# Predição passo 870
# Predição passo 871
# Predição passo 872
# Predição passo 873
# Predição passo 874
# Predição passo 875
# Predição passo 876
# Predição passo 877
# Predição passo 878
# Predição passo 879
# Predição passo 880
# Predição passo 881
# Predição passo 882
# Predição passo 883
# Predição passo 884
# Predição passo 885
# Predição passo 886
# Predição passo 887
# Predição passo 888
# Predição passo 889
# Predição passo 890
# Predição passo 891
# Predição passo 892
# Predição passo 893
# Predição passo 894
# Predição passo 895
# Predição passo 896
# Predição passo 897
# Predição passo 898
# Predição passo 899
# Predição passo 900
# Predição passo 901
# Predição passo 902
# Predição passo 903
# Predição passo 904
# Predição passo 905
# Predição passo 906
# Predição passo 907
# Predição passo 908
# Predição passo 909
# Predição passo 910
# Predição passo 911
# Predição passo 912
# Predição passo 913
# Predição passo 914
# Predição passo 915
# Predição passo 916
# Predição passo 917
# Predição passo 918
# Predição passo 919
# Predição passo 920
# Predição passo 921
# Predição passo 922
# Predição passo 923
# Predição passo 924
# Predição passo 925
# Predição passo 926
# Predição passo 927
# Predição passo 928
# Predição passo 929
# Predição passo 930
# Predição passo 931
# Predição passo 932
# Predição passo 933
# Predição passo 934
# Predição passo 935
# Predição passo 936
# Predição passo 937
# Predição passo 938
# Predição passo 939
# Predição passo 940
# Predição passo 941
# Predição passo 942
# Predição passo 943
# Predição passo 944
# Predição passo 945
# Predição passo 946
# Predição passo 947
# Predição passo 948
# Predição passo 949
# Predição passo 950
# Predição passo 951
# Predição passo 952
# Predição passo 953
# Predição passo 954
# Predição passo 955
# Predição passo 956
# Predição passo 957
# Predição passo 958
# Predição passo 959
# Predição passo 960
# Predição passo 961
# Predição passo 962
# Predição passo 963
# Predição passo 964
# Predição passo 965
# Predição passo 966
# Predição passo 967
# Predição passo 968
# Predição passo 969
# Predição passo 970
# Predição passo 971
# Predição passo 972
# Predição passo 973
# Predição passo 974
# Predição passo 975
# Predição passo 976
# Predição passo 977
# Predição passo 978
# Predição passo 979
# Predição passo 980
# Predição passo 981
# Predição passo 982
# Predição passo 983
# Predição passo 984
# Predição passo 985
# Predição passo 986
# Predição passo 987
# Predição passo 988
# Predição passo 989
# Predição passo 990
# Predição passo 991
# Predição passo 992
# Predição passo 993
# Predição passo 994
# Predição passo 995
# Predição passo 996
# Predição passo 997
# Predição passo 998
# Predição passo 999
# Predição passo 1000
# Predição passo 1001
# Predição passo 1002
# Predição passo 1003
# Predição passo 1004
# Predição passo 1005
# Predição passo 1006
# Predição passo 1007
# Predição passo 1008
# Predição passo 1009
# Predição passo 1010
# Predição passo 1011
# Predição passo 1012
# Predição passo 1013
# Predição passo 1014
# Predição passo 1015
# Predição passo 1016
# Predição passo 1017
# Predição passo 1018
# Predição passo 1019
# Predição passo 1020
# Predição passo 1021
# Predição passo 1022
# Predição passo 1023
# Predição passo 1024
# Predição passo 1025
# Predição passo 1026
# Predição passo 1027
# Predição passo 1028
# Predição passo 1029
# Predição passo 1030
# Predição passo 1031
# Predição passo 1032
# Predição passo 1033
# Predição passo 1034
# Predição passo 1035
# Predição passo 1036
# Predição passo 1037
# Predição passo 1038
# Predição passo 1039
# Predição passo 1040
# Predição passo 1041
# Predição passo 1042
# Predição passo 1043
# Predição passo 1044
# Predição passo 1045
# Predição passo 1046
# Predição passo 1047
# Predição passo 1048
# Predição passo 1049
# Predição passo 1050
# Predição passo 1051
# Predição passo 1052
# Predição passo 1053
# Predição passo 1054
# Predição passo 1055
# Predição passo 1056
# Predição passo 1057
# Predição passo 1058
# Predição passo 1059
# Predição passo 1060
# Predição passo 1061
# Predição passo 1062
# Predição passo 1063
# Predição passo 1064
# Predição passo 1065
# Predição passo 1066
# Predição passo 1067
# Predição passo 1068
# Predição passo 1069
# Predição passo 1070
# Predição passo 1071
# Predição passo 1072
# Predição passo 1073
# Predição passo 1074
# Predição passo 1075
# Predição passo 1076
# Predição passo 1077
# Predição passo 1078
# Predição passo 1079
# Predição passo 1080
# Predição passo 1081
# Predição passo 1082
# Predição passo 1083
# Predição passo 1084
# Predição passo 1085
# Predição passo 1086
# Predição passo 1087
# Predição passo 1088
# Predição passo 1089
# Predição passo 1090
# Predição passo 1091
# Predição passo 1092
# Predição passo 1093
# Predição passo 1094
# Predição passo 1095
# Predição passo 1096
# Predição passo 1097
# Predição passo 1098
# Predição passo 1099
# Predição passo 1100
# Predição passo 1101
# Predição passo 1102
# Predição passo 1103
# Predição passo 1104
# Predição passo 1105
# Predição passo 1106
# Predição passo 1107
# Predição passo 1108
# Predição passo 1109
# Predição passo 1110
# Predição passo 1111
# Predição passo 1112
# Predição passo 1113
# Predição passo 1114
# Predição passo 1115
# Predição passo 1116
# Predição passo 1117
# Predição passo 1118
# Predição passo 1119
# Predição passo 1120
# Predição passo 1121
# Predição passo 1122
# Predição passo 1123
# Predição passo 1124
# Predição passo 1125
# Predição passo 1126
# Predição passo 1127
# Predição passo 1128
# Predição passo 1129
# Predição passo 1130
# Predição passo 1131
# Predição passo 1132
# Predição passo 1133
# Predição passo 1134
# Predição passo 1135
# Predição passo 1136
# Predição passo 1137
# Predição passo 1138
# Predição passo 1139
# Predição passo 1140
# Predição passo 1141
# Predição passo 1142
# Predição passo 1143
# Predição passo 1144
# Predição passo 1145
# Predição passo 1146
# Predição passo 1147
# Predição passo 1148
# Predição passo 1149
# Predição passo 1150
# Predição passo 1151
# Predição passo 1152
# Predição passo 1153
# Predição passo 1154
# Predição passo 1155
# Predição passo 1156
# Predição passo 1157
# Predição passo 1158
# Predição passo 1159
# Predição passo 1160
# Predição passo 1161
# Predição passo 1162
# Predição passo 1163
# Predição passo 1164
# Predição passo 1165
# Predição passo 1166
# Predição passo 1167
# Predição passo 1168
# Predição passo 1169
# Predição passo 1170
# Predição passo 1171
# Predição passo 1172
# Predição passo 1173
# Predição passo 1174
# Predição passo 1175
# Predição passo 1176
# Predição passo 1177
# Predição passo 1178
# Predição passo 1179
# Predição passo 1180
# Predição passo 1181
# Predição passo 1182
# Predição passo 1183
# Predição passo 1184
# Predição passo 1185
# Predição passo 1186
# Predição passo 1187
# Predição passo 1188
# Predição passo 1189
# Predição passo 1190
# Predição passo 1191
# Predição passo 1192
# Predição passo 1193
# Predição passo 1194
# Predição passo 1195
# Predição passo 1196
# Predição passo 1197
# Predição passo 1198
# Predição passo 1199
# Predição passo 1200
# Predição passo 1201
# Predição passo 1202
# Predição passo 1203
# Predição passo 1204
# Predição passo 1205
# Predição passo 1206
# Predição passo 1207
# Predição passo 1208
# Predição passo 1209
# Predição passo 1210
# Predição passo 1211
# Predição passo 1212
# Predição passo 1213
# Predição passo 1214
# Predição passo 1215
# Predição passo 1216
# Predição passo 1217
# Predição passo 1218
# Predição passo 1219
# Predição passo 1220
# Predição passo 1221
# Predição passo 1222
# Predição passo 1223
# Predição passo 1224
# Predição passo 1225
# Predição passo 1226
# Predição passo 1227
# Predição passo 1228
# Predição passo 1229
# Predição passo 1230
# Predição passo 1231
# Predição passo 1232
# Predição passo 1233
# Predição passo 1234
# Predição passo 1235
# Predição passo 1236
# Predição passo 1237
# Predição passo 1238
# Predição passo 1239
# Predição passo 1240
# Predição passo 1241
# Predição passo 1242
# Predição passo 1243
# Predição passo 1244
# Predição passo 1245
# Predição passo 1246
# Predição passo 1247
# Predição passo 1248
# Predição passo 1249
# Predição passo 1250
# Predição passo 1251
# Predição passo 1252
# Predição passo 1253
# Predição passo 1254
# Predição passo 1255
# Predição passo 1256
# Predição passo 1257
# Predição passo 1258
# Predição passo 1259
# Predição passo 1260
# Predição passo 1261
# Predição passo 1262
# Predição passo 1263
# Predição passo 1264
# Predição passo 1265
# Predição passo 1266
# Predição passo 1267
# Predição passo 1268
# Predição passo 1269
# Predição passo 1270
# Predição passo 1271
# Predição passo 1272
# Predição passo 1273
# Predição passo 1274
# Predição passo 1275
# Predição passo 1276
# Predição passo 1277
# Predição passo 1278
# Predição passo 1279
# Predição passo 1280
# Predição passo 1281
# Predição passo 1282
# Predição passo 1283
# Predição passo 1284
# Predição passo 1285
# Predição passo 1286
# Predição passo 1287
# Predição passo 1288
# Predição passo 1289
# Predição passo 1290
# Predição passo 1291
# Predição passo 1292
# Predição passo 1293
# Predição passo 1294
# Predição passo 1295
# Predição passo 1296
# Predição passo 1297
# Predição passo 1298
# Predição passo 1299
# Predição passo 1300
# Predição passo 1301
# Predição passo 1302
# Predição passo 1303
# Predição passo 1304
# Predição passo 1305
# Predição passo 1306
# Predição passo 1307
# Predição passo 1308
# Predição passo 1309
# Predição passo 1310
# Predição passo 1311
# Predição passo 1312
# Predição passo 1313
# Predição passo 1314
# Predição passo 1315
# Predição passo 1316
# Predição passo 1317
# Predição passo 1318
# Predição passo 1319
# Predição passo 1320
# Predição passo 1321
# Predição passo 1322
# Predição passo 1323
# Predição passo 1324
# Predição passo 1325
# Predição passo 1326
# Predição passo 1327
# Predição passo 1328
# Predição passo 1329
# Predição passo 1330
# Predição passo 1331
# Predição passo 1332
# Predição passo 1333
# Predição passo 1334
# Predição passo 1335
# Predição passo 1336
# Predição passo 1337
# Predição passo 1338
# Predição passo 1339
# Predição passo 1340
# Predição passo 1341
# Predição passo 1342
# Predição passo 1343
# Predição passo 1344
# Predição passo 1345
# Predição passo 1346
# Predição passo 1347
# Predição passo 1348
# Predição passo 1349
# Predição passo 1350
# Predição passo 1351
# Predição passo 1352
# Predição passo 1353
# Predição passo 1354
# Predição passo 1355
# Predição passo 1356
# Predição passo 1357
# Predição passo 1358
# Predição passo 1359
# Predição passo 1360
# Predição passo 1361
# Predição passo 1362
# Predição passo 1363
# Predição passo 1364
# Predição passo 1365
# Predição passo 1366
# Predição passo 1367
# Predição passo 1368
# Predição passo 1369
# Predição passo 1370
# Predição passo 1371
# Predição passo 1372
# Predição passo 1373
# Predição passo 1374
# Predição passo 1375
# Predição passo 1376
# Predição passo 1377
# Predição passo 1378
# Predição passo 1379
# Predição passo 1380
# Predição passo 1381
# Predição passo 1382
# Predição passo 1383
# Predição passo 1384
# Predição passo 1385
# Predição passo 1386
# Predição passo 1387
# Predição passo 1388
# Predição passo 1389
# Predição passo 1390
# Predição passo 1391
# Predição passo 1392
# Predição passo 1393
# Predição passo 1394
# Predição passo 1395
# Predição passo 1396
# Predição passo 1397
# Predição passo 1398
# Predição passo 1399
# Predição passo 1400
# Predição passo 1401
# Predição passo 1402
# Predição passo 1403
# Predição passo 1404
# Predição passo 1405
# Predição passo 1406
# Predição passo 1407
# Predição passo 1408
# Predição passo 1409
# Predição passo 1410
# Predição passo 1411
# Predição passo 1412
# Predição passo 1413
# Predição passo 1414
# Predição passo 1415
# Predição passo 1416
# Predição passo 1417
# Predição passo 1418
# Predição passo 1419
# Predição passo 1420
# Predição passo 1421
# Predição passo 1422
# Predição passo 1423
# Predição passo 1424
# Predição passo 1425
# Predição passo 1426
# Predição passo 1427
# Predição passo 1428
# Predição passo 1429
# Predição passo 1430
# Predição passo 1431
# Predição passo 1432
# Predição passo 1433
# Predição passo 1434
# Predição passo 1435
# Predição passo 1436
# Predição passo 1437
# Predição passo 1438
# Predição passo 1439
# Predição passo 1440
# Predição passo 1441
# Predição passo 1442
# Predição passo 1443
# Predição passo 1444
# Predição passo 1445
# Predição passo 1446
# Predição passo 1447
# Predição passo 1448
# Predição passo 1449
# Predição passo 1450
# Predição passo 1451
# Predição passo 1452
# Predição passo 1453
# Predição passo 1454
# Predição passo 1455
# Predição passo 1456
# Predição passo 1457
# Predição passo 1458
# Predição passo 1459
# Predição passo 1460
# Predição passo 1461
# Predição passo 1462
# Predição passo 1463
# Predição passo 1464
# Predição passo 1465
# Predição passo 1466
# Predição passo 1467
# Predição passo 1468
# Predição passo 1469
# Predição passo 1470
# Predição passo 1471
# Predição passo 1472
# Predição passo 1473
# Predição passo 1474
# Predição passo 1475
# Predição passo 1476
# Predição passo 1477
# Predição passo 1478
# Predição passo 1479
# Predição passo 1480
# Predição passo 1481
# Predição passo 1482
# Predição passo 1483
# Predição passo 1484
# Predição passo 1485
# Predição passo 1486
# Predição passo 1487
# Predição passo 1488
# Predição passo 1489
# Predição passo 1490
# Predição passo 1491
# Predição passo 1492
# Predição passo 1493
# Predição passo 1494
# Predição passo 1495
# Predição passo 1496
# Predição passo 1497
# Predição passo 1498
# Predição passo 1499
# Predição passo 1500
# Predição passo 1501
# Predição passo 1502
# Predição passo 1503
# Predição passo 1504
# Predição passo 1505
# Predição passo 1506
# Predição passo 1507
# Predição passo 1508
# Predição passo 1509
# Predição passo 1510
# Predição passo 1511
# Predição passo 1512
# Predição passo 1513
# Predição passo 1514
# Predição passo 1515
# Predição passo 1516
# Predição passo 1517
# Predição passo 1518
# Predição passo 1519
# Predição passo 1520
# Predição passo 1521
# Predição passo 1522
# Predição passo 1523
# Predição passo 1524
# Predição passo 1525
# Predição passo 1526
# Predição passo 1527
# Predição passo 1528
# Predição passo 1529
# Predição passo 1530
# Predição passo 1531
# Predição passo 1532
# Predição passo 1533
# Predição passo 1534
# Predição passo 1535
# Predição passo 1536
# Predição passo 1537
# Predição passo 1538
# Predição passo 1539
# Predição passo 1540
# Predição passo 1541
# Predição passo 1542
# Predição passo 1543
# Predição passo 1544
# Predição passo 1545
# Predição passo 1546
# Predição passo 1547
# Predição passo 1548
# Predição passo 1549
# Predição passo 1550
# Predição passo 1551
# Predição passo 1552
# Predição passo 1553
# Predição passo 1554
# Predição passo 1555
# Predição passo 1556
# Predição passo 1557
# Predição passo 1558
# Predição passo 1559
# Predição passo 1560
# Predição passo 1561
# Predição passo 1562
# Predição passo 1563
# Predição passo 1564
# Predição passo 1565
# Predição passo 1566
# Predição passo 1567
# Predição passo 1568
# Predição passo 1569
# Predição passo 1570
# Predição passo 1571
# Predição passo 1572
# Predição passo 1573
# Predição passo 1574
# Predição passo 1575
# Predição passo 1576
# Predição passo 1577
# Predição passo 1578
# Predição passo 1579
# Predição passo 1580
# Predição passo 1581
# Predição passo 1582
# Predição passo 1583
# Predição passo 1584
# Predição passo 1585
# Predição passo 1586
# Predição passo 1587
# Predição passo 1588
# Predição passo 1589
# Predição passo 1590
# Predição passo 1591
# Predição passo 1592
# Predição passo 1593
# Predição passo 1594
# Predição passo 1595
# Predição passo 1596
# Predição passo 1597
# Predição passo 1598
# Predição passo 1599
# Predição passo 1600
# Predição passo 1601
# Predição passo 1602
# Predição passo 1603
# Predição passo 1604
# Predição passo 1605
# Predição passo 1606
# Predição passo 1607
# Predição passo 1608
# Predição passo 1609
# Predição passo 1610
# Predição passo 1611
# Predição passo 1612
# Predição passo 1613
# Predição passo 1614
# Predição passo 1615
# Predição passo 1616
# Predição passo 1617
# Predição passo 1618
# Predição passo 1619
# Predição passo 1620
# Predição passo 1621
# Predição passo 1622
# Predição passo 1623
# Predição passo 1624
# Predição passo 1625
# Predição passo 1626
# Predição passo 1627
# Predição passo 1628
# Predição passo 1629
# Predição passo 1630
# Predição passo 1631
# Predição passo 1632
# Predição passo 1633
# Predição passo 1634
# Predição passo 1635
# Predição passo 1636
# Predição passo 1637
# Predição passo 1638
# Predição passo 1639
# Predição passo 1640
# Predição passo 1641
# Predição passo 1642
# Predição passo 1643
# Predição passo 1644
# Predição passo 1645
# Predição passo 1646
# Predição passo 1647
# Predição passo 1648
# Predição passo 1649
# Predição passo 1650
# Predição passo 1651
# Predição passo 1652
# Predição passo 1653
# Predição passo 1654
# Predição passo 1655
# Predição passo 1656
# Predição passo 1657
# Predição passo 1658
# Predição passo 1659
# Predição passo 1660
# Predição passo 1661
# Predição passo 1662
# Predição passo 1663
# Predição passo 1664
# Predição passo 1665
# Predição passo 1666
# Predição passo 1667
# Predição passo 1668
# Predição passo 1669
# Predição passo 1670
# Predição passo 1671
# Predição passo 1672
# Predição passo 1673
# Predição passo 1674
# Predição passo 1675
# Predição passo 1676
# Predição passo 1677
# Predição passo 1678
# Predição passo 1679
# Predição passo 1680
# Predição passo 1681
# Predição passo 1682
# Predição passo 1683
# Predição passo 1684
# Predição passo 1685
# Predição passo 1686
# Predição passo 1687
# Predição passo 1688
# Predição passo 1689
# Predição passo 1690
# Predição passo 1691
# Predição passo 1692
# Predição passo 1693
# Predição passo 1694
# Predição passo 1695
# Predição passo 1696
# Predição passo 1697
# Predição passo 1698
# Predição passo 1699
# Predição passo 1700
# Predição passo 1701
# Predição passo 1702
# Predição passo 1703
# Predição passo 1704
# Predição passo 1705
# Predição passo 1706
# Predição passo 1707
# Predição passo 1708
# Predição passo 1709
# Predição passo 1710
# Predição passo 1711
# Predição passo 1712
# Predição passo 1713
# Predição passo 1714
# Predição passo 1715
# Predição passo 1716
# Predição passo 1717
# Predição passo 1718
# Predição passo 1719
# Predição passo 1720
# Predição passo 1721
# Predição passo 1722
# Predição passo 1723
# Predição passo 1724
# Predição passo 1725
# Predição passo 1726
# Predição passo 1727
# Predição passo 1728
# Predição passo 1729
# Predição passo 1730
# Predição passo 1731
# Predição passo 1732
# Predição passo 1733
# Predição passo 1734
# Predição passo 1735
# Predição passo 1736
# Predição passo 1737
# Predição passo 1738
# Predição passo 1739
# Predição passo 1740
# Predição passo 1741
# Predição passo 1742
# Predição passo 1743
# Predição passo 1744
# Predição passo 1745
# Predição passo 1746
# Predição passo 1747
# Predição passo 1748
# Predição passo 1749
# Predição passo 1750
# Predição passo 1751
# Predição passo 1752
# Predição passo 1753
# Predição passo 1754
# Predição passo 1755
# Predição passo 1756
# Predição passo 1757
# Predição passo 1758
# Predição passo 1759
# Predição passo 1760
# Predição passo 1761
# Predição passo 1762
# Predição passo 1763
# Predição passo 1764
# Predição passo 1765
# Predição passo 1766
# Predição passo 1767
# Predição passo 1768
# Predição passo 1769
# Predição passo 1770
# Predição passo 1771
# Predição passo 1772
# Predição passo 1773
# Predição passo 1774
# Predição passo 1775
# Predição passo 1776
# Predição passo 1777
# Predição passo 1778
# Predição passo 1779
# Predição passo 1780
# Predição passo 1781
# Predição passo 1782
# Predição passo 1783
# Predição passo 1784
# Predição passo 1785
# Predição passo 1786
# Predição passo 1787
# Predição passo 1788
# Predição passo 1789
# Predição passo 1790
# Predição passo 1791
# Predição passo 1792
# Predição passo 1793
# Predição passo 1794
# Predição passo 1795
# Predição passo 1796
# Predição passo 1797
# Predição passo 1798
# Predição passo 1799
# Predição passo 1800
# Predição passo 1801
# Predição passo 1802
# Predição passo 1803
# Predição passo 1804
# Predição passo 1805
# Predição passo 1806
# Predição passo 1807
# Predição passo 1808
# Predição passo 1809
# Predição passo 1810
# Predição passo 1811
# Predição passo 1812
# Predição passo 1813
# Predição passo 1814
# Predição passo 1815
# Predição passo 1816
# Predição passo 1817
# Predição passo 1818
# Predição passo 1819
# Predição passo 1820
# Predição passo 1821
# Predição passo 1822
# Predição passo 1823
# Predição passo 1824
# Predição passo 1825
# Predição passo 1826
# Predição passo 1827
# Predição passo 1828
# Predição passo 1829
# Predição passo 1830
# Predição passo 1831
# Predição passo 1832
# Predição passo 1833
# Predição passo 1834
# Predição passo 1835
# Predição passo 1836
# Predição passo 1837
# Predição passo 1838
# Predição passo 1839
# Predição passo 1840
# Predição passo 1841
# Predição passo 1842
# Predição passo 1843
# Predição passo 1844
# Predição passo 1845
# Predição passo 1846
# Predição passo 1847
# Predição passo 1848
# Predição passo 1849
# Predição passo 1850
# Predição passo 1851
# Predição passo 1852
# Predição passo 1853
# Predição passo 1854
# Predição passo 1855
# Predição passo 1856
# Predição passo 1857
# Predição passo 1858
# Predição passo 1859
# Predição passo 1860
# Predição passo 1861
# Predição passo 1862
# Predição passo 1863
# Predição passo 1864
# Predição passo 1865
# Predição passo 1866
# Predição passo 1867
# Predição passo 1868
# Predição passo 1869
# Predição passo 1870
# Predição passo 1871
# Predição passo 1872
# Predição passo 1873
# Predição passo 1874
# Predição passo 1875
# Predição passo 1876
# Predição passo 1877
# Predição passo 1878
# Predição passo 1879
# Predição passo 1880
# Predição passo 1881
# Predição passo 1882
# Predição passo 1883
# Predição passo 1884
# Predição passo 1885
# Predição passo 1886
# Predição passo 1887
# Predição passo 1888
# Predição passo 1889
# Predição passo 1890
# Predição passo 1891
# Predição passo 1892
# Predição passo 1893
# Predição passo 1894
# Predição passo 1895
# Predição passo 1896
# Predição passo 1897
# Predição passo 1898
# Predição passo 1899
# Predição passo 1900
# Predição passo 1901
# Predição passo 1902
# Predição passo 1903
# Predição passo 1904
# Predição passo 1905
# Predição passo 1906
# Predição passo 1907
# Predição passo 1908
# Predição passo 1909
# Predição passo 1910
# Predição passo 1911
# Predição passo 1912
# Predição passo 1913
# Predição passo 1914
# Predição passo 1915
# Predição passo 1916
# Predição passo 1917
# Predição passo 1918
# Predição passo 1919
# Predição passo 1920
# Predição passo 1921
# Predição passo 1922
# Predição passo 1923
# Predição passo 1924
# Predição passo 1925
# Predição passo 1926
# Predição passo 1927
# Predição passo 1928
# Predição passo 1929
# Predição passo 1930
# Predição passo 1931
# Predição passo 1932
# Predição passo 1933
# Predição passo 1934
# Predição passo 1935
# Predição passo 1936
# Predição passo 1937
# Predição passo 1938
# Predição passo 1939
# Predição passo 1940
# Predição passo 1941
# Predição passo 1942
# Predição passo 1943
# Predição passo 1944
# Predição passo 1945
# Predição passo 1946
# Predição passo 1947
# Predição passo 1948
# Predição passo 1949
# Predição passo 1950
# Predição passo 1951
# Predição passo 1952
# Predição passo 1953
# Predição passo 1954
# Predição passo 1955
# Predição passo 1956
# Predição passo 1957
# Predição passo 1958
# Predição passo 1959
# Predição passo 1960
# Predição passo 1961
# Predição passo 1962
# Predição passo 1963
# Predição passo 1964
# Predição passo 1965
# Predição passo 1966
# Predição passo 1967
# Predição passo 1968
# Predição passo 1969
# Predição passo 1970
# Predição passo 1971
# Predição passo 1972
# Predição passo 1973
# Predição passo 1974
# Predição passo 1975
# Predição passo 1976
# Predição passo 1977
# Predição passo 1978
# Predição passo 1979
# Predição passo 1980
# Predição passo 1981
# Predição passo 1982
# Predição passo 1983
# Predição passo 1984
# Predição passo 1985
# Predição passo 1986
# Predição passo 1987
# Predição passo 1988
# Predição passo 1989
# Predição passo 1990
# Predição passo 1991
# Predição passo 1992
# Predição passo 1993
# Predição passo 1994
# Predição passo 1995
# Predição passo 1996
# Predição passo 1997
# Predição passo 1998
# Predição passo 1999
# Predição passo 2000
# Predição passo 2001
# Predição passo 2002
# Predição passo 2003
# Predição passo 2004
# Predição passo 2005
# Predição passo 2006
# Predição passo 2007
# Predição passo 2008
# Predição passo 2009
# Predição passo 2010
# Predição passo 2011
# Predição passo 2012
# Predição passo 2013
# Predição passo 2014
# Predição passo 2015
# Predição passo 2016
# Predição passo 2017
# Predição passo 2018
# Predição passo 2019
# Predição passo 2020
# Predição passo 2021
# Predição passo 2022
# Predição passo 2023
# Predição passo 2024
# Predição passo 2025
# Predição passo 2026
# Predição passo 2027
# Predição passo 2028
# Predição passo 2029
# Predição passo 2030
# Predição passo 2031
# Predição passo 2032
# Predição passo 2033
# Predição passo 2034
# Predição passo 2035
# Predição passo 2036
# Predição passo 2037
# Predição passo 2038
# Predição passo 2039
# Predição passo 2040
# Predição passo 2041
# Predição passo 2042
# Predição passo 2043
# Predição passo 2044
# Predição passo 2045
# Predição passo 2046
# Predição passo 2047
# Predição passo 2048
# Predição passo 2049
# Predição passo 2050
# Predição passo 2051
# Predição passo 2052
# Predição passo 2053
# Predição passo 2054
# Predição passo 2055
# Predição passo 2056
# Predição passo 2057
# Predição passo 2058
# Predição passo 2059
# Predição passo 2060
# Predição passo 2061
# Predição passo 2062
# Predição passo 2063
# Predição passo 2064
# Predição passo 2065
# Predição passo 2066
# Predição passo 2067
# Predição passo 2068
# Predição passo 2069
# Predição passo 2070
# Predição passo 2071
# Predição passo 2072
# Predição passo 2073
# Predição passo 2074
# Predição passo 2075
# Predição passo 2076
# Predição passo 2077
# Predição passo 2078
# Predição passo 2079
# Predição passo 2080
# Predição passo 2081
# Predição passo 2082
# Predição passo 2083
# Predição passo 2084
# Predição passo 2085
# Predição passo 2086
# Predição passo 2087
# Predição passo 2088
# Predição passo 2089
# Predição passo 2090
# Predição passo 2091
# Predição passo 2092
# Predição passo 2093
# Predição passo 2094
# Predição passo 2095
# Predição passo 2096
# Predição passo 2097
# Predição passo 2098
# Predição passo 2099
# Predição passo 2100
# Predição passo 2101
# Predição passo 2102
# Predição passo 2103
# Predição passo 2104
# Predição passo 2105
# Predição passo 2106
# Predição passo 2107
# Predição passo 2108
# Predição passo 2109
# Predição passo 2110
# Predição passo 2111
# Predição passo 2112
# Predição passo 2113
# Predição passo 2114
# Predição passo 2115
# Predição passo 2116
# Predição passo 2117
# Predição passo 2118
# Predição passo 2119
# Predição passo 2120
# Predição passo 2121
# Predição passo 2122
# Predição passo 2123
# Predição passo 2124
# Predição passo 2125
# Predição passo 2126
# Predição passo 2127
# Predição passo 2128
# Predição passo 2129
# Predição passo 2130
# Predição passo 2131
# Predição passo 2132
# Predição passo 2133
# Predição passo 2134
# Predição passo 2135
# Predição passo 2136
# Predição passo 2137
# Predição passo 2138
# Predição passo 2139
# Predição passo 2140
# Predição passo 2141
# Predição passo 2142
# Predição passo 2143
# Predição passo 2144
# Predição passo 2145
# Predição passo 2146
# Predição passo 2147
# Predição passo 2148
# Predição passo 2149
# Predição passo 2150
# Predição passo 2151
# Predição passo 2152
# Predição passo 2153
# Predição passo 2154
# Predição passo 2155
# Predição passo 2156
# Predição passo 2157
# Predição passo 2158
# Predição passo 2159
# Predição passo 2160
# Predição passo 2161
# Predição passo 2162
# Predição passo 2163
# Predição passo 2164
# Predição passo 2165
# Predição passo 2166
# Predição passo 2167
# Predição passo 2168
# Predição passo 2169
# Predição passo 2170
# Predição passo 2171
# Predição passo 2172
# Predição passo 2173
# Predição passo 2174
# Predição passo 2175
# Predição passo 2176
# Predição passo 2177
# Predição passo 2178
# Predição passo 2179
# Predição passo 2180
# Predição passo 2181
# Predição passo 2182
# Predição passo 2183
# Predição passo 2184
# Predição passo 2185
# Predição passo 2186
# Predição passo 2187
# Predição passo 2188
# Predição passo 2189
# Predição passo 2190
# Predição passo 2191
# Predição passo 2192
# Predição passo 2193
# Predição passo 2194
# Predição passo 2195
# Predição passo 2196
# Predição passo 2197
# Predição passo 2198
# Predição passo 2199
# Predição passo 2200
# Predição passo 2201
# Predição passo 2202
# Predição passo 2203
# Predição passo 2204
# Predição passo 2205
# Predição passo 2206
# Predição passo 2207
# Predição passo 2208
# Predição passo 2209
# Predição passo 2210
# Predição passo 2211
# Predição passo 2212
# Predição passo 2213
# Predição passo 2214
# Predição passo 2215
# Predição passo 2216
# Predição passo 2217
# Predição passo 2218
# Predição passo 2219
# Predição passo 2220
# Predição passo 2221
# Predição passo 2222
# Predição passo 2223
# Predição passo 2224
# Predição passo 2225
# Predição passo 2226
# Predição passo 2227
# Predição passo 2228
# Predição passo 2229
# Predição passo 2230
# Predição passo 2231
# Predição passo 2232
# Predição passo 2233
# Predição passo 2234
# Predição passo 2235
# Predição passo 2236
# Predição passo 2237
# Predição passo 2238
# Predição passo 2239
# Predição passo 2240
# Predição passo 2241
# Predição passo 2242
# Predição passo 2243
# Predição passo 2244
# Predição passo 2245
# Predição passo 2246
# Predição passo 2247
# Predição passo 2248
# Predição passo 2249
# Predição passo 2250
# Predição passo 2251
# Predição passo 2252
# Predição passo 2253
# Predição passo 2254
# Predição passo 2255
# Predição passo 2256
# Predição passo 2257
# Predição passo 2258
# Predição passo 2259
# Predição passo 2260
# Predição passo 2261
# Predição passo 2262
# Predição passo 2263
# Predição passo 2264
# Predição passo 2265
# Predição passo 2266
# Predição passo 2267
# Predição passo 2268
# Predição passo 2269
# Predição passo 2270
# Predição passo 2271
# Predição passo 2272
# Predição passo 2273
# Predição passo 2274
# Predição passo 2275
# Predição passo 2276
# Predição passo 2277
# Predição passo 2278
# Predição passo 2279
# Predição passo 2280
# Predição passo 2281
# Predição passo 2282
# Predição passo 2283
# Predição passo 2284
# Predição passo 2285
# Predição passo 2286
# Predição passo 2287
# Predição passo 2288
# Predição passo 2289
# Predição passo 2290
# Predição passo 2291
# Predição passo 2292
# Predição passo 2293
# Predição passo 2294
# Predição passo 2295
# Predição passo 2296
# Predição passo 2297
# Predição passo 2298
# Predição passo 2299
# Predição passo 2300
# Predição passo 2301
# Predição passo 2302
# Predição passo 2303
# Predição passo 2304
# Predição passo 2305
# Predição passo 2306
# Predição passo 2307
# Predição passo 2308
# Predição passo 2309
# Predição passo 2310
# Predição passo 2311
# Predição passo 2312
# Predição passo 2313
# Predição passo 2314
# Predição passo 2315
# Predição passo 2316
# Predição passo 2317
# Predição passo 2318
# Predição passo 2319
# Predição passo 2320
# Predição passo 2321
# Predição passo 2322
# Predição passo 2323
# Predição passo 2324
# Predição passo 2325
# Predição passo 2326
# Predição passo 2327
# Predição passo 2328
# Predição passo 2329
# Predição passo 2330
# Predição passo 2331
# Predição passo 2332
# Predição passo 2333
# Predição passo 2334
# Predição passo 2335
# Predição passo 2336
# Predição passo 2337
# Predição passo 2338
# Predição passo 2339
# Predição passo 2340
# Predição passo 2341
# Predição passo 2342
# Predição passo 2343
# Predição passo 2344
# Predição passo 2345
# Predição passo 2346
# Predição passo 2347
# Predição passo 2348
# Predição passo 2349
# Predição passo 2350
# Predição passo 2351
# Predição passo 2352
# Predição passo 2353
# Predição passo 2354
# Predição passo 2355
# Predição passo 2356
# Predição passo 2357
# Predição passo 2358
# Predição passo 2359
# Predição passo 2360
# Predição passo 2361
# Predição passo 2362
# Predição passo 2363
# Predição passo 2364
# Predição passo 2365
# Predição passo 2366
# Predição passo 2367
# Predição passo 2368
# Predição passo 2369
# Predição passo 2370
# Predição passo 2371
# Predição passo 2372
# Predição passo 2373
# Predição passo 2374
# Predição passo 2375
# Predição passo 2376
# Predição passo 2377
# Predição passo 2378
# Predição passo 2379
# Predição passo 2380
# Predição passo 2381
# Predição passo 2382
# Predição passo 2383
# Predição passo 2384
# Predição passo 2385
# Predição passo 2386
# Predição passo 2387
# Predição passo 2388
# Predição passo 2389
# Predição passo 2390
# Predição passo 2391
# Predição passo 2392
# Predição passo 2393
# Predição passo 2394
# Predição passo 2395
# Predição passo 2396
# Predição passo 2397
# Predição passo 2398
# Predição passo 2399
# Predição passo 2400
# Predição passo 2401
# Predição passo 2402
# Predição passo 2403
# Predição passo 2404
# Predição passo 2405
# Predição passo 2406
# Predição passo 2407
# Predição passo 2408
# Predição passo 2409
# Predição passo 2410
# Predição passo 2411
# Predição passo 2412
# Predição passo 2413
# Predição passo 2414
# Predição passo 2415
# Predição passo 2416
# Predição passo 2417
# Predição passo 2418
# Predição passo 2419
# Predição passo 2420
# Predição passo 2421
# Predição passo 2422
# Predição passo 2423
# Predição passo 2424
# Predição passo 2425
# Predição passo 2426
# Predição passo 2427
# Predição passo 2428
# Predição passo 2429
# Predição passo 2430
# Predição passo 2431
# Predição passo 2432
# Predição passo 2433
# Predição passo 2434
# Predição passo 2435
# Predição passo 2436
# Predição passo 2437
# Predição passo 2438
# Predição passo 2439
# Predição passo 2440
# Predição passo 2441
# Predição passo 2442
# Predição passo 2443
# Predição passo 2444
# Predição passo 2445
# Predição passo 2446
# Predição passo 2447
# Predição passo 2448
# ...
# Predição passo 1877
# Predição passo 1878
# Predição passo 1879
# Predição passo 1880
# Predição passo 1881
# Predição passo 1882
# Predição passo 1883
# Predição passo 1884
# Predição passo 1885
# Predição passo 1886
# Predição passo 1887
# Predição passo 1888
# Predição passo 1889
# Predição passo 1890
# Predição passo 1891
# Predição passo 1892
# Predição passo 1893
# Predição passo 1894
# Predição passo 1895
# Predição passo 1896
# Predição passo 1897
# Predição passo 1898
# Predição passo 1899
# Predição passo 1900
# Predição passo 1901
# Predição passo 1902
# Predição passo 1903
# Predição passo 1904
# Predição passo 1905
# Predição passo 1906
# Predição passo 1907
# Predição passo 1908
# Predição passo 1909
# Predição passo 1910
# Predição passo 1911
# Predição passo 1912
# Predição passo 1913
# Predição passo 1914
# Predição passo 1915
# Predição passo 1916
# Predição passo 1917
# Predição passo 1918
# Predição passo 1919
# Predição passo 1920
# Predição passo 1921
# Predição passo 1922
# Predição passo 1923
# Predição passo 1924
# Predição passo 1925
# Predição passo 1926
# Predição passo 1927
# Predição passo 1928
# Predição passo 1929
# Predição passo 1930
# Predição passo 1931
# Predição passo 1932
# Predição passo 1933
# Predição passo 1934
# Predição passo 1935
# Predição passo 1936
# Predição passo 1937
# Predição passo 1938
# Predição passo 1939
# Predição passo 1940
# Predição passo 1941
# Predição passo 1942
# Predição passo 1943
# Predição passo 1944
# Predição passo 1945
# Predição passo 1946
# Predição passo 1947
# Predição passo 1948
# Predição passo 1949
# Predição passo 1950
# Predição passo 1951
# Predição passo 1952
# Predição passo 1953
# Predição passo 1954
# Predição passo 1955
# Predição passo 1956
# Predição passo 1957
# Predição passo 1958
# Predição passo 1959
# Predição passo 1960
# Predição passo 1961
# Predição passo 1962
# Predição passo 1963
# Predição passo 1964
# Predição passo 1965
# Predição passo 1966
# Predição passo 1967
# Predição passo 1968
# Predição passo 1969
# Predição passo 1970
# Predição passo 1971
# Predição passo 1972
# Predição passo 1973
# Predição passo 1974
# Predição passo 1975
# Predição passo 1976
# Predição passo 1977
# Predição passo 1978
# Predição passo 1979
# Predição passo 1980
# Predição passo 1981
# Predição passo 1982
# Predição passo 1983
# Predição passo 1984
# Predição passo 1985
# Predição passo 1986
# Predição passo 1987
# Predição passo 1988
# Predição passo 1989
# Predição passo 1990
# Predição passo 1991
# Predição passo 1992
# Predição passo 1993
# Predição passo 1994
# Predição passo 1995
# Predição passo 1996
# Predição passo 1997
# Predição passo 1998
# Predição passo 1999
# Predição passo 2000
# Predição passo 2001
# Predição passo 2002
# Predição passo 2003
# Predição passo 2004
# Predição passo 2005
# Predição passo 2006
# Predição passo 2007
# Predição passo 2008
# Predição passo 2009
# Predição passo 2010
# Predição passo 2011
# Predição passo 2012
# Predição passo 2013
# Predição passo 2014
# Predição passo 2015
# Predição passo 2016
# Predição passo 2017
# Predição passo 2018
# Predição passo 2019
# Predição passo 2020
# Predição passo 2021
# Predição passo 2022
# Predição passo 2023
# Predição passo 2024
# Predição passo 2025
# Predição passo 2026
# Predição passo 2027
# Predição passo 2028
# Predição passo 2029
# Predição passo 2030
# Predição passo 2031
# Predição passo 2032
# Predição passo 2033
# Predição passo 2034
# Predição passo 2035
# Predição passo 2036
# Predição passo 2037
# Predição passo 2038
# Predição passo 2039
# Predição passo 2040
# Predição passo 2041
# Predição passo 2042
# Predição passo 2043
# Predição passo 2044
# Predição passo 2045
# Predição passo 2046
# Predição passo 2047
# Predição passo 2048
# Predição passo 2049
# Predição passo 2050
# Predição passo 2051
# Predição passo 2052
# Predição passo 2053
# Predição passo 2054
# Predição passo 2055
# Predição passo 2056
# Predição passo 2057
# Predição passo 2058
# Predição passo 2059
# Predição passo 2060
# Predição passo 2061
# Predição passo 2062
# Predição passo 2063
# Predição passo 2064
# Predição passo 2065
# Predição passo 2066
# Predição passo 2067
# Predição passo 2068
# Predição passo 2069
# Predição passo 2070
# Predição passo 2071
# Predição passo 2072
# Predição passo 2073
# Predição passo 2074
# Predição passo 2075
# Predição passo 2076
# Predição passo 2077
# Predição passo 2078
# Predição passo 2079
# Predição passo 2080
# Predição passo 2081
# Predição passo 2082
# Predição passo 2083
# Predição passo 2084
# Predição passo 2085
# Predição passo 2086
# Predição passo 2087
# Predição passo 2088
# Predição passo 2089
# Predição passo 2090
# Predição passo 2091
# Predição passo 2092
# Predição passo 2093
# Predição passo 2094
# Predição passo 2095
# Predição passo 2096
# Predição passo 2097
# Predição passo 2098
# Predição passo 2099
# Predição passo 2100
# Predição passo 2101
# Predição passo 2102
# Predição passo 2103
# Predição passo 2104
# Predição passo 2105
# Predição passo 2106
# Predição passo 2107
# Predição passo 2108
# Predição passo 2109
# Predição passo 2110
# Predição passo 2111
# Predição passo 2112
# Predição passo 2113
# Predição passo 2114
# Predição passo 2115
# Predição passo 2116
# Predição passo 2117
# Predição passo 2118
# Predição passo 2119
# Predição passo 2120
# Predição passo 2121
# Predição passo 2122
# Predição passo 2123
# Predição passo 2124
# Predição passo 2125
# Predição passo 2126
# Predição passo 2127
# Predição passo 2128
# Predição passo 2129
# Predição passo 2130
# Predição passo 2131
# Predição passo 2132
# Predição passo 2133
# Predição passo 2134
# Predição passo 2135
# Predição passo 2136
# Predição passo 2137
# Predição passo 2138
# Predição passo 2139
# Predição passo 2140
# Predição passo 2141
# Predição passo 2142
# Predição passo 2143
# Predição passo 2144
# Predição passo 2145
# Predição passo 2146
# Predição passo 2147
# Predição passo 2148
# Predição passo 2149
# Predição passo 2150
# Predição passo 2151
# Predição passo 2152
# Predição passo 2153
# Predição passo 2154
# Predição passo 2155
# Predição passo 2156
# Predição passo 2157
# Predição passo 2158
# Predição passo 2159
# Predição passo 2160
# Predição passo 2161
# Predição passo 2162
# Predição passo 2163
# Predição passo 2164
# Predição passo 2165
# Predição passo 2166
# Predição passo 2167
# Predição passo 2168
# Predição passo 2169
# Predição passo 2170
# Predição passo 2171
# Predição passo 2172
# Predição passo 2173
# Predição passo 2174
# Predição passo 2175
# Predição passo 2176
# Predição passo 2177
# Predição passo 2178
# Predição passo 2179
# Predição passo 2180
# Predição passo 2181
# Predição passo 2182
# Predição passo 2183
# Predição passo 2184
# Predição passo 2185
# Predição passo 2186
# Predição passo 2187
# Predição passo 2188
# Predição passo 2189
# Predição passo 2190
# Predição passo 2191
# Predição passo 2192
# Predição passo 2193
# Predição passo 2194
# Predição passo 2195
# Predição passo 2196
# Predição passo 2197
# Predição passo 2198
# Predição passo 2199
# Predição passo 2200
# Predição passo 2201
# Predição passo 2202
# Predição passo 2203
# Predição passo 2204
# Predição passo 2205
# Predição passo 2206
# Predição passo 2207
# Predição passo 2208
# Predição passo 2209
# Predição passo 2210
# Predição passo 2211
# Predição passo 2212
# Predição passo 2213
# Predição passo 2214
# Predição passo 2215
# Predição passo 2216
# Predição passo 2217
# Predição passo 2218
# Predição passo 2219
# Predição passo 2220
# Predição passo 2221
# Predição passo 2222
# Predição passo 2223
# Predição passo 2224
# Predição passo 2225
# Predição passo 2226
# Predição passo 2227
# Predição passo 2228
# Predição passo 2229
# Predição passo 2230
# Predição passo 2231
# Predição passo 2232
# Predição passo 2233
# Predição passo 2234
# Predição passo 2235
# Predição passo 2236
# Predição passo 2237
# Predição passo 2238
# Predição passo 2239
# Predição passo 2240
# Predição passo 2241
# Predição passo 2242
# Predição passo 2243
# Predição passo 2244
# Predição passo 2245
# Predição passo 2246
# Predição passo 2247
# Predição passo 2248
# Predição passo 2249
# Predição passo 2250
# Predição passo 2251
# Predição passo 2252
# Predição passo 2253
# Predição passo 2254
# Predição passo 2255
# Predição passo 2256
# Predição passo 2257
# Predição passo 2258
# Predição passo 2259
# Predição passo 2260
# Predição passo 2261
# Predição passo 2262
# Predição passo 2263
# Predição passo 2264
# Predição passo 2265
# Predição passo 2266
# Predição passo 2267
# Predição passo 2268
# Predição passo 2269
# Predição passo 2270
# Predição passo 2271
# Predição passo 2272
# Predição passo 2273
# Predição passo 2274
# Predição passo 2275
# Predição passo 2276
# Predição passo 2277
# Predição passo 2278
# Predição passo 2279
# Predição passo 2280
# Predição passo 2281
# Predição passo 2282
# Predição passo 2283
# Predição passo 2284
# Predição passo 2285
# Predição passo 2286
# Predição passo 2287
# Predição passo 2288
# Predição passo 2289
# Predição passo 2290
# Predição passo 2291
# Predição passo 2292
# Predição passo 2293
# Predição passo 2294
# Predição passo 2295
# Predição passo 2296
# Predição passo 2297
# Predição passo 2298
# Predição passo 2299
# Predição passo 2300
# Predição passo 2301
# Predição passo 2302
# Predição passo 2303
# Predição passo 2304
# Predição passo 2305
# Predição passo 2306
# Predição passo 2307
# Predição passo 2308
# Predição passo 2309
# Predição passo 2310
# Predição passo 2311
# Predição passo 2312
# Predição passo 2313
# Predição passo 2314
# Predição passo 2315
# Predição passo 2316
# Predição passo 2317
# Predição passo 2318
# Predição passo 2319
# Predição passo 2320
# Predição passo 2321
# Predição passo 2322
# Predição passo 2323
# Predição passo 2324
# Predição passo 2325
# Predição passo 2326
# Predição passo 2327
# Predição passo 2328
# Predição passo 2329
# Predição passo 2330
# Predição passo 2331
# Predição passo 2332
# Predição passo 2333
# Predição passo 2334
# Predição passo 2335
# Predição passo 2336
# Predição passo 2337
# Predição passo 2338
# Predição passo 2339
# Predição passo 2340
# Predição passo 2341
# Predição passo 2342
# Predição passo 2343
# Predição passo 2344
# Predição passo 2345
# Predição passo 2346
# Predição passo 2347
# Predição passo 2348
# Predição passo 2349
# Predição passo 2350
# Predição passo 2351
# Predição passo 2352
# Predição passo 2353
# Predição passo 2354
# Predição passo 2355
# Predição passo 2356
# Predição passo 2357
# Predição passo 2358
# Predição passo 2359
# Predição passo 2360
# Predição passo 2361
# Predição passo 2362
# Predição passo 2363
# Predição passo 2364
# Predição passo 2365
# Predição passo 2366
# Predição passo 2367
# Predição passo 2368
# Predição passo 2369
# Predição passo 2370
# Predição passo 2371
# Predição passo 2372
# Predição passo 2373
# Predição passo 2374
# Predição passo 2375
# Predição passo 2376
# Predição passo 2377
# Predição passo 2378
# Predição passo 2379
# Predição passo 2380
# Predição passo 2381
# Predição passo 2382
# Predição passo 2383
# Predição passo 2384
# Predição passo 2385
# Predição passo 2386
# Predição passo 2387
# Predição passo 2388
# Predição passo 2389
# Predição passo 2390
# Predição passo 2391
# Predição passo 2392
# Predição passo 2393
# Predição passo 2394
# Predição passo 2395
# Predição passo 2396
# Predição passo 2397
# Predição passo 2398
# Predição passo 2399
# Predição passo 2400
# Predição passo 2401
# Predição passo 2402
# Predição passo 2403
# Predição passo 2404
# Predição passo 2405
# Predição passo 2406
# Predição passo 2407
# Predição passo 2408
# Predição passo 2409
# Predição passo 2410
# Predição passo 2411
# Predição passo 2412
# Predição passo 2413
# Predição passo 2414
# Predição passo 2415
# Predição passo 2416
# Predição passo 2417
# Predição passo 2418
# Predição passo 2419
# Predição passo 2420
# Predição passo 2421
# Predição passo 2422
# Predição passo 2423
# Predição passo 2424
# Predição passo 2425
# Predição passo 2426
# Predição passo 2427
# Predição passo 2428
# Predição passo 2429
# Predição passo 2430
# Predição passo 2431
# Predição passo 2432
# Predição passo 2433
# Predição passo 2434
# Predição passo 2435
# Predição passo 2436
# Predição passo 2437
# Predição passo 2438
# Predição passo 2439
# Predição passo 2440
# Predição passo 2441
# Predição passo 2442
# Predição passo 2443
# Predição passo 2444
# Predição passo 2445
# Predição passo 2446
# Predição passo 2447
# Predição passo 2448
# Predição passo 2449
# Predição passo 2450
# Predição passo 2451
# Predição passo 2452
# Predição passo 2453
# Predição passo 2454
# Predição passo 2455
# Predição passo 2456
# Predição passo 2457
# Predição passo 2458
# Predição passo 2459
# Predição passo 2460
# Predição passo 2461
# Predição passo 2462
# Predição passo 2463
# Predição passo 2464
# Predição passo 2465
# Predição passo 2466
# Predição passo 2467
# Predição passo 2468
# Predição passo 2469
# Predição passo 2470
# Predição passo 2471
# Predição passo 2472
# Predição passo 2473
# Predição passo 2474
# Predição passo 2475
# Predição passo 2476
# Predição passo 2477
# Predição passo 2478
# Predição passo 2479
# Predição passo 2480
# Predição passo 2481
# Predição passo 2482
# Predição passo 2483
# Predição passo 2484
# Predição passo 2485
# Predição passo 2486
# Predição passo 2487
# Predição passo 2488
# Predição passo 2489
# Predição passo 2490
# Predição passo 2491
# Predição passo 2492
# Predição passo 2493
# Predição passo 2494
# Predição passo 2495
# Predição passo 2496
# Predição passo 2497
# Predição passo 2498
# Predição passo 2499
# Predição passo 2500
# Predição passo 2501
# Predição passo 2502
# Predição passo 2503
# Predição passo 2504
# Predição passo 2505
# Predição passo 2506
# Predição passo 2507
# Predição passo 2508
# Predição passo 2509
# Predição passo 2510
# Predição passo 2511
# Predição passo 2512
# Predição passo 2513
# Predição passo 2514
# Predição passo 2515
# Predição passo 2516
# Predição passo 2517
# Predição passo 2518
# Predição passo 2519
# Predição passo 2520
# Predição passo 2521
# Predição passo 2522
# Predição passo 2523
# Predição passo 2524
# Predição passo 2525
# Predição passo 2526
# Predição passo 2527
# Predição passo 2528
# Predição passo 2529
# Predição passo 2530
# Predição passo 2531
# Predição passo 2532
# Predição passo 2533
# Predição passo 2534
# Predição passo 2535
# Predição passo 2536
# Predição passo 2537
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 performance_exog, residuals_exog = fit_ar_model_exog(df = criptos_diff, target_column = 'Bitcoin', starting_point_percent = STARTING_POINT, lags_list = LAGS)
#
# Cell In[17], line 20, in fit_ar_model_exog(df, target_column, starting_point_percent, lags_list)
#      16 print(f'Treinando com variáveis exógenas: {combo}')
#      18 X_subset = X[list(combo)]  # Seleciona as colunas da combinação
# ---> 20 predictions = one_step_ahead_forecasting_AR_exog(y=y, X=X_subset, starting_point_percent=starting_point_percent, lags=lags)
#      22 actual = y.iloc[int(len(y) * starting_point_percent):].values
#      23 actual = actual[:len(predictions)]  # Garantir tamanhos compatíveis
#
# Cell In[16], line 40, in one_step_ahead_forecasting_AR_exog(y, X, starting_point_percent, lags)
#      37     X_train = np.vstack([X_train, X_test[i]])
#      39     # Ajustar modelo novamente
# ---> 40     model = AutoReg(y_train, lags=lags, exog=X_train)
#      41     model_fit = model.fit()
#      43 return np.array(predictions)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\ar_model.py:261, in AutoReg.__init__(self, endog, lags, trend, seasonal, exog, hold_back, period, missing, deterministic, old_names)
#     252     warnings.warn(
#     253         "old_names will be removed after the 0.14 release. You should "
#     254         "stop setting this parameter and use the new names.",
#     255         FutureWarning,
#     256         stacklevel=2,
#     257     )
#     258 self._lags, self._hold_back = self._check_lags(
#     259     lags, int_like(hold_back, "hold_back", optional=True)
#     260 )
# --> 261 self._setup_regressors()
#     262 self.nobs = self._y.shape[0]
#     263 self.data.xnames = self.exog_names
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\ar_model.py:355, in AutoReg._setup_regressors(self)
#     353 exog_names = []
#     354 endog_names = self.endog_names
# --> 355 x, y = lagmat(self.endog, maxlag, original="sep")
#     356 exog_names.extend(
#     357     [endog_names + f".L{lag}" for lag in self._lags]
#     358 )
#     359 if len(self._lags) < maxlag:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\tsatools.py:398, in lagmat(x, maxlag, trim, original, use_pandas)
#     396 if maxlag >= nobs:
#     397     raise ValueError("maxlag should be < nobs")
# --> 398 lm = np.zeros((nobs + maxlag, nvar * (maxlag + 1)))
#     399 for k in range(0, int(maxlag + 1)):
#     400     lm[
#     401     maxlag - k: nobs + maxlag - k,
#     402     nvar * (maxlag - k): nvar * (maxlag - k + 1),
#     403     ] = x
#
# KeyboardInterrupt:

# %%
performance_exog.to_excel(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\output_data\ar_exog_performance_table.xlsx")

# %%
performance_exog

# %% [markdown]
# ## Using logs

# %%
criptos_log = np.log(criptos)

# %%
criptos_log_diff = criptos_log - criptos_log.shift(1)
criptos_log_diff = criptos_log_diff.dropna()

# %%
criptos_diff

# %%
criptos_log_diff

# %% [markdown]
# ### Simple AR(1) models

# %%
performance_log, residuals_log = fit_ar_model(criptos_log_diff, starting_point_percent = STARTING_POINT, lags_list = LAGS)

# %%
performance_log.to_excel(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\output_data\ar_log_performance_table.xlsx")

# %% [markdown]
# ### Exogenous

# %%
performance_exog_log, residuals_exog_log = fit_ar_model_exog(df = criptos_log_diff, target_column = 'Bitcoin', starting_point_percent = STARTING_POINT, lags_list = LAGS)

# %%
performance_exog_log.to_excel(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\output_data\ar_exog_log_performance_table.xlsx")

# %%
performance_exog_log

# %% [markdown]
# ## Residual analysis

# %%
residuals = residuals.iloc[:,:5]

# %%
residuals_exog =  residuals_exog.iloc[:, :4]

# %%
residuals_exog_log = residuals_exog_log.iloc[:, :4]

# %% [markdown]
# ### Scatter plot

# %%
sns.pairplot(residuals)

plt.tight_layout()

# %%
sns.pairplot(residuals_exog)

plt.tight_layout()

# %%
sns.pairplot(residuals_log)

plt.tight_layout()

# %%
residuals_log.corr()

# %%
sns.pairplot(residuals_exog_log)

plt.tight_layout()

# %% [markdown]
# ### Time

# %%
plot_residuals(residuals)

# %%
plot_residuals(residuals_exog)

# %%
plot_residuals(residuals_log)

# %%
plot_residuals(residuals_exog_log)

# %% [markdown]
# ## ML models

# %% [markdown]
# ## Model validation

# %%
decision_tree = {
    "Decision Tree": {
        "model": DecisionTreeRegressor(random_state=42),
        "params": {
            "splitter": ["best"],
            "max_depth": [int(3), int(5), int(10), int(50)],
            "min_samples_split": [int(2), int(5),  int(50)],
            "min_samples_leaf": [int(1), int(2), int(10)],
            "max_features": ["sqrt"],
            "max_leaf_nodes": [int(10), int(20), int(50), int(100)],
        }
    }}

# %%
rf = {"Random Forest": {
        "model": RandomForestRegressor(random_state=42),
        "params": {
            "n_estimators": [int(100), int(200), int(500)],
            "max_depth": [int(5), int(30), int(50)],
            "min_samples_split": [int(2), int(5), int(20)],
            "min_samples_leaf": [int(1), int(3), int(6)],
            "bootstrap": [False],  
            "oob_score": [False],
        }
    }}

# %%
xgb = {"XGBoost": {
        "model": XGBRegressor(random_state=42),
        "params": {
            "n_estimators": [int(100), int(200), int(500)],
            "max_depth": [int(3), int(10), int(15)],
            "learning_rate": [0.001, 0.01, 0.1],
            "subsample": [0.7, 0.9, 1.0],
            "colsample_bytree": [0.7, 0.9, 1.0],
            "gamma": [0.1, 0.2, 0.3],
            "reg_alpha": [0.1, 0.5, 1],
            "reg_lambda": [0.1, 0.5, 1],
            "min_child_weight": [int(1), int(3), int(5)]
        }
}}

# %% [markdown]
# ## 1 lag models

# %%
one_lag_results_tree = optimize_and_evaluate_one_lag(criptos_diff, decision_tree)
# Out:
# 🔍 Processing column: Bitcoin
# ⚙️ Optimizing model: Decision Tree for Bitcoin
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.13 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.13 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.17 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.14 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.17 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.18 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.19 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.18 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.18 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.28 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.28 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.32 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.29 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.29 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.33 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.28 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.29 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.29 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.32 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.35 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.37 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.34 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.35 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.38 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.33 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.33 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.36 seconds
# ✅ Decision Tree for Bitcoin - Final MSE on Test: 0.0000
#
# 🔍 Processing column: Dogecoin
# ⚙️ Optimizing model: Decision Tree for Dogecoin
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.07 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.07 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.13 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.10 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.12 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.27 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.27 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.27 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.27 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# ...
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.18 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.13 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.11 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.16 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.17 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.17 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.20 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.14 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.26 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.28 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.25 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.17 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.23 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.17 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.17 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.15 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.21 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.19 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.39 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.22 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.24 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.39 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.33 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.33 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.40 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.28 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.36 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.62 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.37 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.38 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.63 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.51 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.50 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.55 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.39 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.50 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.66 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.51 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.57 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.70 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 2, 'splitter': 'best'}
# Total training time: 0.65 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# Total training time: 0.59 seconds
# Testando a combinação {'max_depth': 50, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_samples_split': 50, 'splitter': 'best'}
# Total training time: 0.64 seconds
# ✅ Decision Tree for Solana - Final MSE on Test: 0.0001

# %%
one_lag_results.to_excel(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\output_data\results_tree_ml.xlsx")

# %%
one_lag_results_rf = optimize_and_evaluate_one_lag(criptos_diff, rf)
# Out:
# 🔍 Processing column: Bitcoin
# ⚙️ Optimizing model: Random Forest for Bitcoin
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 11.39 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 22.70 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 56.34 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 11.46 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 22.44 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 56.51 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 11.14 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 16.72 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 20.62 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.45 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 6.80 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 17.09 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.38 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 6.80 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 16.93 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.39 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 6.78 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 16.90 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.39 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 6.79 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 16.91 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.41 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 6.77 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 16.87 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.41 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 6.80 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 16.93 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 15.99 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 34.60 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 97.42 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 33.37 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 71.63 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 90.55 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.19 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 35.03 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 95.48 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 17.60 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 34.52 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 86.84 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 17.12 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 34.72 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 84.93 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 16.51 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 33.38 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 83.71 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 16.33 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 32.04 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 81.79 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 15.96 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 33.17 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 87.62 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 16.82 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 33.46 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 82.11 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 23.08 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 45.52 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 114.80 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 21.02 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 42.39 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 107.47 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 20.25 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 40.25 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 98.27 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 20.05 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 41.07 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 102.64 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 20.54 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 40.81 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 102.55 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 20.46 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 39.53 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 99.56 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.16 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 39.63 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 97.26 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.46 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 39.06 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 97.36 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.16 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 37.34 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 97.72 seconds
# ✅ Random Forest for Bitcoin - Final MSE on Test: 0.0000
#
# 🔍 Processing column: Dogecoin
# ⚙️ Optimizing model: Random Forest for Dogecoin
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.12 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.72 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.50 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.17 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.72 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.53 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.03 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 8.21 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.77 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.80 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.97 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.65 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.68 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.87 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.17 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.41 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.96 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.44 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.18 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.54 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.41 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.34 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.68 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.68 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.83 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 8.14 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.52 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 20.69 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 39.50 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 98.62 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.42 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 38.98 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 98.43 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.61 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 38.96 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 95.21 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 17.98 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.89 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 93.04 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.05 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 37.22 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 95.26 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.43 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.70 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 94.08 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 17.07 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 34.48 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 84.72 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 17.05 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 33.87 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 85.01 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 16.60 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 34.04 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 85.40 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 27.28 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 54.24 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 135.65 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 25.35 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 52.86 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 135.31 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 24.52 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 49.45 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 127.83 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 24.07 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 47.83 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 120.78 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 24.16 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 47.92 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 118.58 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 23.55 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 47.62 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 116.27 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.60 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 39.14 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 96.79 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.96 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 38.61 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 96.00 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.26 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 38.37 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 95.07 seconds
# ✅ Random Forest for Dogecoin - Final MSE on Test: 0.0000
#
# 🔍 Processing column: Chainlink
# ⚙️ Optimizing model: Random Forest for Chainlink
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.38 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.77 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 20.12 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.95 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 8.06 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 20.41 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.78 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.74 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.24 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.66 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.78 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.83 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.21 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 8.16 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 18.87 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.75 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.73 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.65 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.51 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 8.08 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 18.83 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 3.67 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.75 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.31 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 4.36 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 7.86 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 5, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 19.30 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 19.01 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 39.60 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 98.85 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.71 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 37.66 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 93.56 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.10 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 37.16 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 91.45 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.84 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.77 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 91.84 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.74 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.71 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 93.53 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.59 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.77 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 3, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 90.81 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 17.54 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.96 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 89.19 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 18.55 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.00 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 89.05 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 17.75 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 36.16 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 88.85 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 24.96 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 49.32 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 125.69 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 23.62 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 47.53 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}
# Total training time: 116.26 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100, 'oob_score': False}
# Total training time: 22.33 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200, 'oob_score': False}
# Total training time: 92.11 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500, 'oob_score': False}
# Total training time: 297.67 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'oob_score': False}
# Total training time: 62.99 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200, 'oob_score': False}
# Total training time: 121.24 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500, 'oob_score': False}
# Total training time: 312.19 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100, 'oob_score': False}
# Total training time: 61.99 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 200, 'oob_score': False}
# Total training time: 127.52 seconds
# Testando a combinação {'bootstrap': False, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 500, 'oob_score': False}

# %%
one_lag_results_rf.to_excel(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\output_data\results_rf_ml.xlsx")

# %%
one_lag_results_xgb = optimize_and_evaluate_one_lag(criptos_diff, xgb)

# %%
one_lag_results_xgb.to_excel(r"C:\Users\Caio\Documents\Documentos\IC - Cripto\output_data\results_xgb_ml.xlsx")

# %% [markdown]
# ## Adding exogenous variables

# %%
best_results = results_df.sort_values(by="mse").groupby("model").first().reset_index()
print(best_results)
